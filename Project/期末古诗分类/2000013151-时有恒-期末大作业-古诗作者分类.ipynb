# %% [markdown]
# # RNN序列编码-分类期末大作业
#
# 本次大作业要求手动实现双向LSTM+基于attention的聚合模型，并用于古诗作者预测的序列分类任务。**请先阅读ppt中的作业说明。**

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import random
import numpy as np

from tqdm import tqdm

device = torch.device("cuda")
import torch.optim as optim

random.seed(1)
np.random.seed(1)
torch.manual_seed(1)

# %% [markdown]
# ## 1. 加载数据

# %% [markdown]
# 数据位于`data`文件夹中，每一行对应一个样例，格式为“诗句 作者”。下面的代码将数据文件读取到`train_data`, `valid_data`和`test_data`中，并根据训练集中的数据构造词表`word2idx`/`idx2word`和标签集合`label2idx`/`idx2label`。

# %%
word2idx = {"<unk>": 0}
label2idx = {}
idx2word = ["<unk>"]
idx2label = []

train_data = []
with open("data/train.txt", encoding="utf-8") as f:
    for line in f:
        text, author = line.strip().split()
        for c in text:
            if c not in word2idx:
                word2idx[c] = len(idx2word)
                idx2word.append(c)
        if author not in label2idx:
            label2idx[author] = len(idx2label)
            idx2label.append(author)
        train_data.append((text, author))

valid_data = []
with open("data/valid.txt", encoding="utf-8") as f:
    for line in f:
        text, author = line.strip().split()
        valid_data.append((text, author))

test_data = []
with open("data/test.txt", encoding="utf-8") as f:
    for line in f:
        text, author = line.strip().split()
        test_data.append((text, author))

# %%
print(len(word2idx), len(idx2word), len(label2idx), len(idx2label))
print(len(train_data), len(valid_data), len(test_data))
# Out:
# 4941 4941 5 5
# 11271 1408 1410

# %% [markdown]
# **请完成下面的函数，其功能为给定一句古诗和一个作者，构造RNN的输入。** 这里需要用到上面构造的词表和标签集合，对于不在词表中的字用\<unk\>代替。

# %%
def make_data(text, author):
    """
    输入
        text: str
        author: str
    输出
        x: LongTensor, shape = (1, text_length)
        y: LongTensor, shape = (1,)
    """
    word_list = []
    for w in text:
        try:
            word_list.append(word2idx[w]) 
        except:
            word_list.append(0)

    x = torch.LongTensor(word_list).reshape(1,-1)
    y = torch.LongTensor([label2idx[author]])
    return x, y

x, y = make_data(*train_data[1])
x.shape, y.shape
# Out:
# (torch.Size([1, 24]), torch.Size([1]))

# %% [markdown]
# ## 2. LSTM算子（单个时间片作为输入）

# %%
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(LSTM, self).__init__()
        self.f = nn.Linear(input_size + hidden_size, hidden_size)
        self.i = nn.Linear(input_size + hidden_size, hidden_size)
        self.o = nn.Linear(input_size + hidden_size, hidden_size)
        self.g = nn.Linear(input_size + hidden_size, hidden_size)
    
    def forward(self, ht, ct, xt):
        # ht: 1 * hidden_size
        # ct: 1 * hidden_size
        # xt: 1 * input_size
        input_combined = torch.cat((xt, ht), 1)
        ft = torch.sigmoid(self.f(input_combined))
        it = torch.sigmoid(self.i(input_combined))
        ot = torch.sigmoid(self.o(input_combined))
        gt = torch.tanh(self.g(input_combined))
        ct = ft * ct + it * gt
        ht = ot * torch.tanh(ct)
        return ht, ct

# %% [markdown]
# ## 3. 实现双向LSTM（整个序列作为输入）
#
# **要求使用上面提供的LSTM算子，不要调用torch.nn.LSTM**

# %%
class BiLSTM(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(BiLSTM, self).__init__()

        self.register_buffer("_float", torch.zeros(1, hidden_size))
        self.rnn1 = LSTM(input_size, hidden_size)
        self.rnn2 = LSTM(input_size, hidden_size)
        self.h1, self.c1 = self.init_h_and_c()
        self.h2, self.c2 = self.init_h_and_c()
        
    def init_h_and_c(self): 
        h = torch.zeros_like(self._float)
        c = torch.zeros_like(self._float)
        return h, c
    
    def lstm_loop(self, input, rnn, ht, ct):
        """
        input:  (length , input_size)
        rnn: 用到的算子
        ht: (1, hiddensize)
        ct: (1, hiddensize)
        返回值：lstm_output: (length, hidden_size)
        """
        output = []
        for x in input:
            xt = x.reshape(1,-1) # (1, hidden_size)
            ht, ct = rnn(xt, ht, ct)
            output.append(ht)
        lstm_output = torch.vstack(output) # (length, hidden_size)

        return lstm_output


    def forward(self, input):
        """
        输入
            input: 1 * length * input_size
        输出
            hiddens :(1, length, hidden_size * 2)
        """

        # recurrent, f_cx = self.rnn1(input[0])
        recurrent = self.lstm_loop(input[0], self.rnn1, self.h1, self.c1) # (length, hidden_size) 
        
        fwd = [recurrent]
        
        forward = torch.stack(fwd, dim=0).squeeze(1) # (1, length, hidden_size)

        input_reverse = torch.flip(input, dims=[1]) # 翻转

        recurrent_b= self.lstm_loop(input_reverse[0], self.rnn1, self.h2, self.c2) # (length, hidden_size)
        
        bwd = [recurrent_b] 
        backward = torch.stack(bwd, dim=0).squeeze(1) # (1, length, hidden_size)
        
        hiddens = torch.cat((forward, backward), -1) # (1, length, hidden_size * 2)
        
        return hiddens

# %% [markdown]
# ## 4. 实现基于attention的聚合机制

# %%
class Attention(nn.Module):
    def __init__(self, hidden_size):
        super(Attention, self).__init__()
        self.hidden_size = hidden_size
        # 这里不加bias，就可以达到效果了
        self.qt = nn.Linear(hidden_size, 1, bias = False)
    def forward(self, hiddens):
        """
        输入
            hiddens: 1 * length * hidden_size
        输出
            attn_outputs: 1 * hidden_size
        """
        h = hiddens[0] # (length, hidden_size) 
        qh = self.qt(h) # (length, 1)

        alpha = F.softmax(qh, 1) # (length, 1)

        attn_outputs = alpha.T @ h # (1, hidden_size)

        return attn_outputs # (1, hidden_size)

# %% [markdown]
# ## 5. 利用上述模块搭建序列分类模型
#
# 参考模型结构：Embedding – BiLSTM – Attention – Linear – LogSoftmax

# %%
class EncoderRNN(nn.Module):
    def __init__(self, num_vocab, embedding_dim, hidden_size, num_classes):
        """
        参数
            num_vocab: 词表大小
            embedding_dim: 词向量维数
            hidden_size: 隐状态维数
            num_classes: 类别数量
        """
        super(EncoderRNN, self).__init__()
        self.num_vocab = num_vocab
        self.embedding_dim = embedding_dim
        self.hidden_size = hidden_size
        self.num_classes = num_classes
        
        self.embedding = nn.Embedding(num_vocab, embedding_dim)
        self.lstm = BiLSTM(embedding_dim, hidden_size)
        self.attention = Attention(hidden_size * 2)
        self.out = nn.Linear(hidden_size * 2, num_classes)

    def forward(self, X):
        """
        输入
            x: (1, length), LongTensor
        输出
            outputs: (1, num_classes)
        """
        input = self.embedding(X) # (1, length, embedding_dim) 

        output = self.lstm(input) # (length, batch_size, 2*hidden_size)
        
        attn_output = self.attention(output) # (1, 2*hidden_size)
        
        linear_output = self.out(attn_output) # (1, num_classes)
        
        output = F.log_softmax(linear_output, dim=1) # (1, num_classes)

        return output

# %%
model = EncoderRNN(num_vocab = len(word2idx), embedding_dim = 16, hidden_size = 6, num_classes = 5)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# ## 6. 请利用上述模型在古诗作者分类任务上进行训练和测试
#
# 要求选取在验证集上效果最好的模型，输出测试集上的准确率、confusion matrix以及macro-precision/recall/F1，并打印部分测试样例及预测结果。

# %%
# 训练
EPOCH = 5
maxAccuracy = 0 # 最高准确率
for epoch in range(EPOCH):
    for data in tqdm(train_data):
        input_batch, target_batch = make_data(*data)
        
        optimizer.zero_grad()
        output = model(input_batch)
        loss = criterion(output, target_batch)
        loss.backward()
        optimizer.step()

    # 一个epoch结束计算一下正确率
    correct_count = 0
    for d in valid_data:
        input_batch, target_batch = make_data(*d)
        output = model(input_batch)
        if torch.argmax(output).item() == target_batch.item():
            correct_count += 1
    accuracy = correct_count/len(valid_data)
            
    print(f'EPOCH = {epoch+1}， accuracy = {accuracy}')
            
    if accuracy > maxAccuracy:
        # 如果准确率提高了，那么就保存新模型
        maxAccuracy = accuracy
        torch.save(model,'best_model')
# Out:
# 100%|██████████| 11271/11271 [03:56<00:00, 47.67it/s]
# EPOCH = 1， accuracy = 0.49573863636363635
# 100%|██████████| 11271/11271 [03:59<00:00, 47.09it/s]
# EPOCH = 2， accuracy = 0.5475852272727273
# 100%|██████████| 11271/11271 [04:25<00:00, 42.49it/s]
# EPOCH = 3， accuracy = 0.5830965909090909
# 100%|██████████| 11271/11271 [04:33<00:00, 41.14it/s]
# EPOCH = 4， accuracy = 0.5894886363636364
# 100%|██████████| 11271/11271 [04:00<00:00, 46.91it/s]
# EPOCH = 5， accuracy = 0.5973011363636364

# %%
# 测试
best_model = torch.load("./best_model")

y_true = [label2idx[data[1]] for data in test_data]

y_pred = []
for n, data in enumerate(test_data):
    input_batch, target_batch = make_data(*data)    

    output = best_model(input_batch)
    predict = torch.argmax(output).item()
    y_pred.append(predict)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
print("测试集上准确率: ",accuracy_score(y_true, y_pred),"\n")

print("confusion_matrix: \n",confusion_matrix(y_true, y_pred),"\n")

print("precision_score: ",precision_score(y_true, y_pred, average="macro"),"\n")

print("recall_score: ",recall_score(y_true, y_pred, average="macro"),"\n")

print("f1_score: ",f1_score(y_true, y_pred, average="macro"),"\n")
# Out:
# 测试集上准确率:  0.6212765957446809
#
# confusion_matrix:
#  [[ 43  21  56  27  13]
#  [ 12 310  64  21   7]
#  [ 16  40 376  28   8]
#  [ 16  25  55 124  17]
#  [ 20  17  44  27  23]]
#
# precision_score:  0.5337796119179676
#
# recall_score:  0.5039480688178053
#
# f1_score:  0.5089730830266238

# %%
# 部分测试样例与结果
authors_pred = [idx2label[i] for i in y_pred]
list(zip(test_data,authors_pred))
# 每一行输出的第一个作者是正确答案，第二个作者是预测的
# Out:
# [(('舊日重陽日，傳杯不放杯。即今蓬鬢改，但愧菊花開。', '杜甫'), '杜甫'),
#  (('熊羆交黑槊，賓客滿青油。今日文章主，梁王不姓劉。', '劉禹錫'), '杜甫'),
#  (('晝號夜哭兼幽顯，早晚星關雪涕收。', '李商隱'), '杜甫'),
#  (('玉壘高桐拂玉繩，上含非霧下含冰。', '李商隱'), '杜牧'),
#  (('相思樹上合歡枝，紫鳳青鸞共羽儀。', '李商隱'), '劉禹錫'),
#  (('空齋寂寂不生塵，藥物方書繞病身。纖草數莖勝靜地，', '劉禹錫'), '劉禹錫'),
#  (('陰騭今如此，天災未可無。莫憑牲玉請，便望救焦枯。', '李商隱'), '李白'),
#  (('露索秦宮井，風弦漢殿箏。幾時綿竹頌，擬薦子虛名。', '李商隱'), '杜甫'),
#  (('開從綠條上，散逐香風遠。故取花落時，悠揚占春晚。', '劉禹錫'), '李白'),
#  (('顧于韓蔡內，辨眼工小字。分日示諸王，鉤深法更秘。', '杜甫'), '杜甫'),
#  (('貧家羞好客，語拙覺辭繁。三朝空錯莫，對飯卻慚冤。', '李白'), '杜甫'),
#  (('吾愛王子晉，得道伊洛濱。金骨既不毀，玉顏長自春。', '李白'), '李白'),
#  (('開元皇帝東封時，百神受職爭賓士。千鈞猛簴順流下，', '劉禹錫'), '劉禹錫'),
#  (('微雨秋栽竹，孤燈夜讀書。憐君亦同志，晚歲傍山居。', '杜牧'), '杜甫'),
#  (('蘆白疑粘鬢，楓丹欲照心。歸期無雁報，旅抱有猿侵。', '李商隱'), '杜甫'),
#  (('烈士擊玉壺，壯心惜暮年。三杯拂劍舞秋月，', '李白'), '李白'),
#  (('江色綠且明，茫茫與天平。逶迤巴山盡，搖曳楚雲行。', '李白'), '李白'),
#  (('豈思鱗作簟，仍計腹為燈。浩蕩天池路，翱翔欲化鵬。', '李商隱'), '李商隱'),
#  (('黃衫年少來宜數，不見堂前東逝波。', '杜甫'), '杜甫'),
#  (('繁弦迸關紐，塞管裂圓蘆。眾音不能逐，嫋嫋穿雲衢。', '杜牧'), '杜甫'),
#  (('柴荊具茶茗，徑路通林丘。與子成二老，來往亦風流。', '杜甫'), '杜甫'),
#  (('一政政官軋軋，一年年老駸駸。', '劉禹錫'), '杜牧'),
#  (('采菱寒刺上，蹋藕野泥中。素楫分曹往，金盤小徑通。', '杜甫'), '杜甫'),
#  (('茅土加名數，山河誓始終。策行遺戰伐，契合動昭融。', '杜甫'), '杜甫'),
#  (('孰謂漢陵人，來作江汀客。載筆念無能，捧籌慚所畫。', '杜牧'), '杜甫'),
#  (('歲陽初盛動，王化久磷緇。為入蒼梧廟，看雲哭九疑。', '杜甫'), '杜甫'),
#  (('鵩鳥長沙諱，犀牛蜀郡憐。素車猶慟哭，寶劍谷高懸。', '杜甫'), '杜甫'),
#  (('未泛盈樽酒，徒沾清露輝。當榮君不采，飄落欲何依。', '李白'), '李白'),
#  (('爭名古豈然，鍵捷欻不閉。例及吾家詩，曠懷掃氛翳。', '杜甫'), '杜甫'),
#  (('紆餘帶竹村，蠶鄉足砧杵。塍泉落環佩，畦苗差纂組。', '杜牧'), '杜牧'),
#  (('煬帝雷塘土，迷藏有舊樓。誰家唱水調，明月滿揚州。', '杜牧'), '劉禹錫'),
#  (('稍下巫山峽，猶銜白帝城。氣沈全浦暗，輪仄半樓明。', '杜甫'), '杜甫'),
#  (('鼓角緣邊郡，川原欲夜時。秋聽殷地發，風散入雲悲。', '杜甫'), '李白'),
#  (('披拂雲寧在，淹留景不延。風期終破浪，水怪莫飛涎。', '杜甫'), '李白'),
#  (('此生任春草，垂老獨漂萍。倘憶山陽會，悲歌在一聽。', '杜甫'), '杜甫'),
#  (('鐘陵靄千里，帶郭西江水。朱檻照河宮，旗亭綠雲裏。', '劉禹錫'), '李白'),
#  (('往與惠荀輩，中年滄洲期。天高無消息，棄我忽若遺。', '杜甫'), '李白'),
#  (('曾為掾吏趨三輔，憶在潼關詩興多。巫峽忽如瞻華嶽，', '杜甫'), '杜甫'),
#  (('裂素持作書，將寄萬里懷。眷眷待遠信，竟歲無人來。', '李白'), '李白'),
#  (('猿掛時相學，鷗行炯自如。瞿唐春欲至，定卜瀼西居。', '杜甫'), '杜甫'),
#  (('金花折風帽，白馬小遲回。翩翩舞廣袖，似鳥海東來。', '李白'), '李白'),
#  (('懶心似江水，日夜向滄洲。不道含香賤，其如鑷白休。', '杜甫'), '杜甫'),
#  (('今日春光太漂蕩，謝家輕絮沈郎錢。', '李商隱'), '李商隱'),
#  (('短小精悍姿，屹然強寇敵。貫穿百萬眾，出入由咫尺。', '杜甫'), '杜甫'),
#  (('骯髒不能就珪組，至今空揚高蹈名。夫子工文絕世奇，', '李白'), '杜甫'),
#  (('憶妾深閨裏，煙塵不曾識。嫁與長干人，沙頭候風色。', '李白'), '李白'),
#  (('弟子貧原憲，諸生老伏虔。師資謙未達，鄉党敬何先。', '杜甫'), '杜甫'),
#  (('天子旌旗度，法王龍象隨。知懷去家歎，經此益遲遲。', '劉禹錫'), '李白'),
#  (('擊築飲美酒，劍歌易水湄。經過燕太子，結托並州兒。', '李白'), '李白'),
#  (('童稚思諸子，交朋列友于。情乖清酒送，望絕撫墳呼。', '杜甫'), '杜甫'),
#  (('古來唯有王文度，重見平生竺道人。', '劉禹錫'), '劉禹錫'),
#  (('流水淘沙不暫停，前波未滅後波生。', '劉禹錫'), '劉禹錫'),
#  (('渡江如昨日，黃葉向人飛。敬亭愜素尚，弭棹流清輝。', '李白'), '李白'),
#  (('舊事參差夢，新程邐迤秋。故人如見憶，時到寺東樓。', '杜牧'), '劉禹錫'),
#  (('百勝本自有前期，一飛由來無定所。風俗如狂重此時，', '劉禹錫'), '劉禹錫'),
#  (('忽逢乘馬客，恍若驚麏顧。腰斧上高山，意行無舊路。', '劉禹錫'), '劉禹錫'),
#  (('風吹巨焰作，河棹騰煙柱。勢俗焚昆侖，光彌焮洲渚。', '杜甫'), '杜甫'),
#  (('是時左馮翊，天下第一理。貴臣持牙璋，優詔發青紙。', '劉禹錫'), '劉禹錫'),
#  (('青青屋東麻，散亂床上書。不意遠山雨，夜來複何如。', '杜甫'), '杜甫'),
#  (('此草最可珍，何必貴龍須。織作玉床席，欣承清夜娛。', '李白'), '李白'),
#  (('歲杪風物動，雪餘宮苑晴。兔園賓客至，金穀管弦聲。', '劉禹錫'), '劉禹錫'),
#  (('星星仙語人聽盡，卻向五雲翻翅飛。', '劉禹錫'), '劉禹錫'),
#  (('紙尾得新什，眉頭還暫開。此時同雁鶩，池上一徘徊。', '劉禹錫'), '劉禹錫'),
#  (('南遊炎海甸，浩蕩從此辭。窮途仗神道，世亂輕土宜。', '杜甫'), '杜甫'),
#  (('帆濕去悠悠，停橈宿渡頭。亂煙迷野岸，獨鳥出中流。', '杜牧'), '杜甫'),
#  (('安知天漢上，白日懸高名。海客去已久，誰人測沉冥。', '李白'), '李白'),
#  (('岑夫子，丹丘生，將進酒，君莫停。與君歌一曲，', '李白'), '李白'),
#  (('恩疏寵不及，桃李傷春風。淫樂意何極，金輿向回中。', '李白'), '李白'),
#  (('陰風西北來，慘澹隨回鶻。其王願助順，其俗善馳突。', '杜甫'), '杜甫'),
#  (('命世須人瑞，匡君在嶽靈。氣和熏北陸，襟曠納東溟。', '杜牧'), '杜甫'),
#  (('漳濱臥起恣閒遊，宣室征還未白頭。舊隱來尋通德里，', '劉禹錫'), '杜甫'),
#  (('箭空在，人今戰死不復回。不忍見此物，焚之已成灰。', '李白'), '杜甫'),
#  (('無計回船下，空愁避酒難。主人情爛熳，持答翠琅玕。', '杜甫'), '杜甫'),
#  (('消中日伏枕，臥久塵及屨。豈無平肩輿，莫辨望鄉路。', '杜甫'), '杜甫'),
#  (('啼烏爭引子，鳴鶴不歸林。下食遭泥去，高飛恨久陰。', '杜甫'), '杜甫'),
#  (('右銀台路雪三尺，鳳詔裁成當直歸。', '李商隱'), '李商隱'),
#  (('只須伐竹開荒徑，倚杖穿花聽馬嘶。', '杜甫'), '杜甫'),
#  (('一桃複一李，井上占年芳。笑處如臨鏡，窺時不隱牆。', '李商隱'), '劉禹錫'),
#  (('勿受外嫌猜，同姓古所敦。', '杜甫'), '劉禹錫'),
#  (('所插小藩籬，本亦有堤防。終然掁撥損，得吝千葉黃。', '杜甫'), '杜甫'),
#  (('金障既特設，珠簾亦高褰。捋須蹇不顧，坐在禦榻前。', '李商隱'), '李商隱'),
#  (('青天何歷歷，明星如白石。黃姑與織女，相去不盈尺。', '李白'), '李白'),
#  (('不是愛花即肯死，只恐花盡老相催。', '杜甫'), '杜甫'),
#  (('遂性同漁父，成名異魯連。篙師煩爾送，朱夏及寒泉。', '杜甫'), '杜甫'),
#  (('蜀船紅錦重，越橐水沈堆。處處皆華表，淮王奈卻回。', '杜牧'), '杜牧'),
#  (('大屋去高棟，長城掃遺堞。平生白羽扇，零落蛟龍匣。', '杜甫'), '杜甫'),
#  (('私好初童稚，官榮見子孫。流年休掛念，萬事至無言。', '杜牧'), '杜牧'),
#  (('嚴陵台下桐江水，解釣鱸魚能幾人。', '杜牧'), '李白'),
#  (('蒼梧大火落，暑服莫輕擲。此物雖過時，是妾手中跡。', '李白'), '李白'),
#  (('青牛文梓赤金簧，玫瑰寶柱秋雁行。斂蛾收袂凝清光，', '劉禹錫'), '李商隱'),
#  (('我李百萬葉，柯條布中州。天開青雲器，日為蒼生憂。', '李白'), '李白'),
#  (('地崩山摧壯士死，然後天梯石棧方鉤連。', '李白'), '李白'),
#  (('紺殿橫江上，青山落鏡中。岸回沙不盡，日映水成空。', '李白'), '李白'),
#  (('藥纂西極名，兵流指諸掌。貫穿無遺恨，薈蕞何技癢。', '杜甫'), '李商隱'),
#  (('園陵固有神，掃灑數不缺。煌煌太宗業，樹立甚宏達。', '杜甫'), '杜甫'),
#  (('君王若悟治安論，安史何人敢弄兵。', '杜牧'), '李白'),
#  (('自謂頗挺出，立登要路津。致君堯舜上，再使風俗淳。', '杜甫'), '杜甫'),
#  (('白髮對綠酒，強歌心已摧。君不見梁王池上月，', '李白'), '李白'),
#  (('鴻雁及羔羊，有禮太古前。行飛與跪乳，識序如知恩。', '杜甫'), '劉禹錫'),
#  (('吳山高，越水清，握手無言傷別情。將欲辭君掛帆去，', '李白'), '李白'),
#  (('群雞正亂叫，客至雞鬥爭。驅雞上樹木，始聞叩柴荊。', '杜甫'), '劉禹錫'),
#  (('三十六離宮，樓臺與天通。閣道步行月，美人愁煙空。', '李白'), '李白'),
#  (('杖藜尋晚巷，炙背近牆暄。人見幽居僻，吾知拙養尊。', '杜甫'), '杜甫'),
#  (('長沙男子東林師，閑讀藝經工弈棋。有時凝思如入定，', '劉禹錫'), '李商隱'),
#  (('把酒從衣濕，吟詩信杖扶。敢論才見忌，實有醉如愚。', '杜甫'), '杜甫'),
#  (('驊騮入窮巷，必脫黃金轡。一論朋友難，遲暮敢失墜。', '杜甫'), '杜甫'),
#  (('南望青松架短壑，安得赤腳蹋層冰。', '杜甫'), '杜甫'),
#  (('青田歸路遠，丹桂舊巢空。矯翼知何處，天涯不可窮。', '杜牧'), '李白'),
#  (('亦擬村南買煙舍，子孫相約事耕耘。', '李商隱'), '劉禹錫'),
#  (('紫茸垂組縷，金縷攢鋒穎。露溽暗傳香，風輕徐就影。', '劉禹錫'), '劉禹錫'),
#  (('列國兵戈暗，今王德教淳。要聞除猰貐，休作畫麒麟。', '杜甫'), '杜甫'),
#  (('呀然閬城南，枕帶巴江腹。芰荷入異縣，粳稻共比屋。', '杜甫'), '杜甫'),
#  (('雜種雖高壘，長驅甚建瓴。焚香淑景殿，漲水望雲亭。', '杜甫'), '杜甫'),
#  (('漢酺聞奏鈞天樂，願得風吹到夜郎。', '李白'), '劉禹錫'),
#  (('共賀高禖應，將陳壽酒歡。金星壓芒角，銀漢轉波瀾。', '李商隱'), '李商隱'),
#  (('宮女晚知曙，祠官朝見星。空梁簇畫戟，陰井敲銅瓶。', '杜甫'), '劉禹錫'),
#  (('憶昔驪山宮，冬移含元仗。天寒大羽獵，此物神俱王。', '杜甫'), '杜甫'),
#  (('卻憶蓬池阮公詠，因吟淥水揚洪波。洪波浩蕩迷舊國，', '李白'), '李白'),
#  (('怡然敬父執，問我來何方。問答乃未已，兒女羅酒漿。', '杜甫'), '杜甫'),
#  (('我有結綠珍，久藏濁水泥。時人棄此物，乃與燕瑉齊。', '李白'), '李白'),
#  (('齊歌送清揚，起舞亂參差。賓隨落葉散，帽逐秋風吹。', '李白'), '李白'),
#  (('世間人事有何窮，過後思量儘是空。', '劉禹錫'), '劉禹錫'),
#  (('丞相祠堂何處尋，錦官城外柏森森。映階碧草自春色，', '杜甫'), '杜牧'),
#  (('古時杜宇稱望帝，魂作杜鵑何微細。跳枝竄葉樹木中，', '杜甫'), '李商隱'),
#  (('今年灌口損戶口，此事或恐為神羞。終藉堤防出眾力，', '杜甫'), '杜甫'),
#  (('秦家築城避胡處，漢家還有烽火然。烽火然不息，', '李白'), '杜甫'),
#  (('多病紛倚薄，少留改歲年。絕域誰慰懷，開顏喜名賢。', '杜甫'), '杜甫'),
#  (('西方像教毀，南海繡衣行。金橐寧回顧，珠簟肯一棖。', '杜牧'), '李商隱'),
#  (('田家有美酒，落日與之傾。醉罷弄歸月，遙欣稚子迎。', '李白'), '李白'),
#  (('愁作秋浦客，強看秋浦花。山川如剡縣，風日似長沙。', '李白'), '李白'),
#  (('大江動我前，洶若溟渤寬。篙師暗理楫，歌笑輕波瀾。', '杜甫'), '李白'),
#  (('存者無消息，死者為塵泥。賤子因陣敗，歸來尋舊蹊。', '杜甫'), '李商隱'),
#  (('郢中白雪且莫吟，子夜吳歌動君心。動君心，冀君賞，', '李白'), '李白'),
#  (('徒聞斬蛟劍，無複爨犀船。使者隨秋色，迢迢獨上天。', '杜甫'), '杜甫'),
#  (('竹叢身後長，台勢雨來傾。六尺孤安在，人間未有名。', '劉禹錫'), '杜甫'),
#  (('蚩尤終戮辱，胡羯漫倡狂。會待襖氛靜，論文暫裹糧。', '杜甫'), '杜甫'),
#  (('滿眼悲陳事，逢人少舊僚。煙霞為老伴，蒲柳任先凋。', '劉禹錫'), '劉禹錫'),
#  (('來書語絕妙，遠客驚深眷。食蕨不願餘，茅茨眼中見。', '杜甫'), '杜甫'),
#  (('莫度清秋吟蟋蟀，早聞黃閣畫麒麟。', '杜甫'), '李白'),
#  (('杜陵蕭次君，遷少去官頻。寂寞憐吾道，依稀似古人。', '杜牧'), '杜甫'),
#  (('樂毅倘再生，於今亦奔亡。蹉跎不得意，驅馬還貴鄉。', '李白'), '杜甫'),
#  (('城外春風吹酒旗，行人揮袂日西時。', '劉禹錫'), '劉禹錫'),
#  (('蹉跎陶唐人，鞭撻日月久。中間屈賈輩，讒毀竟自取。', '杜甫'), '李白'),
#  (('忽憶雨時秋井塌，古人白骨生青苔，如何不飲令心哀。', '杜甫'), '李白'),
#  (('天子九九八十一萬歲，長傾萬歲杯。', '李白'), '李白'),
#  (('疏雨洗空曠，秋標驚意新。大熱去酷吏，清風來故人。', '杜牧'), '杜甫'),
#  (('一盞新羅酒，淩晨恐易消。歸應沖鼓半，去不待笙調。', '李商隱'), '劉禹錫'),
#  (('惟昔武皇后，臨軒禦乾坤。多士盡儒冠，墨客藹雲屯。', '杜甫'), '杜甫'),
#  (('三杯吐然諾，五嶽倒為輕。眼花耳熱後，意氣素霓生。', '李白'), '李白'),
#  (('滅見息群動，獵微窮至精。桃花有源水，可以保吾生。', '李白'), '李白'),
#  (('深誠補王室，戮力自元昆。三止錦江沸，獨清玉壘昏。', '杜甫'), '杜甫'),
#  (('追呼故舊連宵飲，直到天明興未闌。', '劉禹錫'), '杜甫'),
#  (('群吏謁新府，舊賓沾素衣。歌堂忽暮哭，賀雀盡驚飛。', '劉禹錫'), '杜甫'),
#  (('憐君冰玉清迥之明心，情不極兮意已深。', '李白'), '李白'),
#  (('句吳亭東千里秋，放歌曾作昔年遊。青苔寺裏無馬跡，', '杜牧'), '劉禹錫'),
#  (('匈奴以殺戮為耕作，古來唯見白骨黃沙田。', '李白'), '李白'),
#  (('賢者須喪亡，讒人尚堆堵。予於後四年，諫官事明主。', '杜牧'), '劉禹錫'),
#  (('青田歸路遠，月桂舊巢空。矯翼知何處，天涯不可窮。', '杜牧'), '李白'),
#  (('蛟龍得雨鬐鬣動，螮蝀飲河形影聯。刺史臨流褰翠幃，', '劉禹錫'), '劉禹錫'),
#  (('淮西既是平安地，鴉路今無羽檄飛。', '劉禹錫'), '杜牧'),
#  (('桀犬尚吠堯，匈奴笑千秋。中夜四五歎，常為大國憂。', '李白'), '李白'),
#  (('萍泛無休日，桃陰想舊蹊。吹噓人所羨，騰躍事仍睽。', '杜甫'), '杜甫'),
#  (('光景不可回，六龍轉天車。荊人泣美玉，魯叟悲匏瓜。', '李白'), '李白'),
#  (('幹元元年春，萬姓始安宅。舟也衣彩衣，告我欲遠適。', '杜甫'), '杜甫'),
#  (('張良未遇韓信貧，劉項存亡在兩臣。暫到下邳受兵略，', '李白'), '杜甫'),
#  (('高鳥黃雲暮，寒蟬碧樹秋。湖南冬不雪，吾病得淹留。', '杜甫'), '杜甫'),
#  (('仙院文房隔舊宮，當時盛事盡成空。墨池半在頹垣下，', '劉禹錫'), '劉禹錫'),
#  (('日落水流西複東，春光不盡柳何窮。巫娥廟裏低含雨，', '杜牧'), '杜甫'),
#  (('花月窮遊宴，炎天避鬱蒸。研寒金井水，簷動玉壺冰。', '杜甫'), '李白'),
#  (('是時當朏魄，陰物恣騰振。日光吐鯨背，劍影開龍鱗。', '劉禹錫'), '劉禹錫'),
#  (('原野曠超緬，關河紛雜重。清暉映竹日，翠色明雲松。', '李白'), '杜甫'),
#  (('紫陌紅塵拂面來，無人不道看花回。', '劉禹錫'), '劉禹錫'),
#  (('春日垂霜鬢，天隅把繡衣。故人從此去，寥落寸心違。', '杜甫'), '杜甫'),
#  (('何慚聶政姊，萬古共驚嗟。', '李白'), '李白'),
#  (('朅來已永久，頹思如迴圈。飄飄限江裔，想像空留滯。', '李白'), '李白'),
#  (('海色動遠山，天雞已先鳴。銀台出倒景，白浪翻長鯨。', '李白'), '李白'),
#  (('千千石楠樹，萬萬女貞林。山山白鷺滿，澗澗白猿吟。', '李白'), '李白'),
#  (('蜀國多仙山，峨眉邈難匹。周流試登覽，絕怪安可息。', '李白'), '李白'),
#  (('秋毫不犯三吳悅，春日遙看五色光。', '李白'), '李白'),
#  (('湘妃廟下已春盡，虞帝城前初日曛。謝游橋上澄江館，', '李商隱'), '劉禹錫'),
#  (('日晚上樓招估客，軻峨大艑落帆來。', '劉禹錫'), '劉禹錫'),
#  (('徙倚三層閣，摩挲七寶刀。庾郎年最少，青草妒春袍。', '李商隱'), '李商隱'),
#  (('江上人家桃樹枝，春寒細雨出疏籬。影遭碧水潛勾引，', '杜甫'), '杜甫'),
#  (('今人嗤點流傳賦，不覺前賢畏後生。', '杜甫'), '李白'),
#  (('爐煙消盡寒燈晦，童子開門雪滿松。', '李商隱'), '李商隱'),
#  (('徒雲逢剪削，豈謂見偏裝。鳳節輕雕日，鸞花薄飾香。', '杜牧'), '李商隱'),
#  (('太常樓船聲嗷嘈，問兵刮寇趨下牢。牧出令奔飛百艘，', '杜甫'), '杜甫'),
#  (('西漢開支郡，南朝號戚藩。四封當列宿，百雉俯清沅。', '劉禹錫'), '杜甫'),
#  (('終然備外飾，駕馭何所益。我有平肩輿，前途猶准的。', '杜甫'), '杜甫'),
#  (('昔在朗陵東，學禪白眉空。大地了鏡徹，迴旋寄輪風。', '李白'), '李白'),
#  (('蠻絲系條脫，妍眼和香屑。壽宮不惜鑄南人，', '李商隱'), '杜甫'),
#  (('濯錦江邊兩岸花，春風吹浪正淘沙。', '劉禹錫'), '杜甫'),
#  (('楚岸通秋屐，胡床面夕畦。藉糟分汁滓，甕醬落提攜。', '杜甫'), '杜甫'),
#  (('泣別目眷眷，傷心步遲遲。願言保明德，王室佇清夷。', '李白'), '李白'),
#  (('人生幾何春已夏，不放香醪如蜜甜。', '杜甫'), '李商隱'),
#  (('勸君多買長安酒，南陌東城占取春。', '劉禹錫'), '劉禹錫'),
#  (('張陳竟火滅，蕭朱亦星離。眾鳥集榮柯，窮魚守枯池。', '李白'), '杜牧'),
#  (('龜山蔽魯國，有斧且無柯。歸來歸去來，宵濟越洪波。', '李白'), '李白'),
#  (('震澤生奇石，沉潛得地靈。初辭水府出，猶帶龍宮腥。', '劉禹錫'), '劉禹錫'),
#  (('故人入我夢，明我長相憶。恐非平生魂，路遠不可測。', '杜甫'), '李白'),
#  (('搖落從此始，別離含遠情。聞君當是夕，倚瑟吟商聲。', '劉禹錫'), '劉禹錫'),
#  (('萬古至今同此恨，無如一醉盡忘機。', '劉禹錫'), '杜牧'),
#  (('且醉習家池，莫看墮淚碑。山公欲上馬，笑殺襄陽兒。', '李白'), '李白'),
#  (('祖帳管弦絕，客帆西風生。回車已不見，猶聽馬嘶聲。', '劉禹錫'), '劉禹錫'),
#  (('素色愁明湖，秋渚晦寒姿。疇昔紫芳意，已過黃發期。', '李白'), '李白'),
#  (('溪水悠悠春自來，草堂無主燕飛回。', '劉禹錫'), '李白'),
#  (('月寒江清夜沉沉，美人一笑千黃金，垂羅舞縠揚哀音。', '李白'), '李白'),
#  (('失學從兒懶，長貧任婦愁。百年渾得醉，一月不梳頭。', '杜甫'), '杜甫'),
#  (('煬帝行宮汴水濱，數株殘柳不勝春。', '劉禹錫'), '劉禹錫'),
#  (('無媒徑路草蕭蕭，自古雲林遠市朝。', '杜牧'), '劉禹錫'),
#  (('遙想敬亭春欲暮，百花飛盡柳花初。', '劉禹錫'), '李商隱'),
#  (('曾主魚書輕刺史，今朝自請左魚來。', '劉禹錫'), '杜甫'),
#  (('有獲人爭賀，歡謠眾共聽。一州驚閱寶，千里遠揚舲。', '劉禹錫'), '劉禹錫'),
#  (('眼邊江舸何匆促，未待安流逆浪歸。', '杜甫'), '杜甫'),
#  (('長明燈是前朝焰，曾照青青年少時。', '劉禹錫'), '李商隱'),
#  (('二紀征南恩與舊，此時丹旐玉山西。', '李商隱'), '劉禹錫'),
#  (('宋玉事楚王，立身本高潔。巫山賦彩雲，郢路歌白雪。', '李白'), '李白'),
#  (('蒼江程未息，黑水夢何頻。明月輕橈去，唯應釣赤鱗。', '杜牧'), '杜牧'),
#  (('謝家離別正淒涼，少傅臨岐賭佩囊。', '李商隱'), '劉禹錫'),
#  (('雲車來何遲，撫幾空歎息。', '李白'), '李白'),
#  (('壇下雪初霽，南城凍欲生。齋心祠上帝，高步領名卿。', '劉禹錫'), '劉禹錫'),
#  (('折花不見我，淚下如流泉。小兒名伯禽，與姊亦齊肩。', '李白'), '李白'),
#  (('曆下辭姜被，關西得孟鄰。早通交契密，晚接道流新。', '杜甫'), '杜甫'),
#  (('憑幾看魚樂，回鞭急鳥棲。漸知秋實美，幽徑恐多蹊。', '杜甫'), '杜甫'),
#  (('崩騰天寶末，塵暗燕南垂。爟火入咸陽，詔征神武師。', '劉禹錫'), '杜甫'),
#  (('老病忌拘束，應接喪精神。江村意自放，林木心所欣。', '杜甫'), '杜甫'),
#  (('敬亭山下百頃竹，中有詩人小謝城。城高跨樓滿金碧，', '杜牧'), '杜甫'),
#  (('洗拂青雲上，當時賤如泥。朝歌鼓刀叟，虎變磻溪中。', '李白'), '李白'),
#  (('有女悲初寡，無男泣過門。朝爭屈原草，廟餒莫敖魂。', '李商隱'), '杜甫'),
#  (('山禽引子哺紅果，溪友得錢留白魚。', '杜甫'), '杜甫'),
#  (('嘉蔬沒混濁，時菊碎榛叢。鷹隼亦屈猛，烏鳶何所蒙。', '杜甫'), '杜甫'),
#  (('今日好南風，商旅相催發。沙頭檣竿上，始見春江闊。', '劉禹錫'), '杜甫'),
#  (('鮫人弄機杼，貝闕駢紅紫。珠蛤吐玲瓏，文鰩翔旖旎。', '劉禹錫'), '杜牧'),
#  (('庾信哀雖久，何顒好不忘。白牛車遠近，且欲上慈航。', '杜甫'), '杜甫'),
#  (('披君貂襜褕，對君白玉壺。雪花酒上滅，頓覺夜寒無。', '李白'), '李白'),
#  (('昔在鳳翔都，共通金閨籍。天子猶蒙塵，東郊暗長戟。', '杜甫'), '杜甫'),
#  (('杳杳東山攜漢妓，泠泠修竹待王歸。', '杜甫'), '李商隱'),
#  (('若逢廣坐問羊酪，從此知名在一言。', '劉禹錫'), '劉禹錫'),
#  (('峽口大江間，西南控百蠻。城欹連粉堞，岸斷更青山。', '杜甫'), '杜甫'),
#  (('暫行新林浦，定醉金陵月。莫惜一雁書，音塵坐胡越。', '李白'), '李白'),
#  (('黃河西岸是吾蜀，欲須供給家無粟。', '杜甫'), '杜甫'),
#  (('重陽不相知，載酒任所適。手持一枝菊，調笑二千石。', '李白'), '李白'),
#  (('春來常早起，幽事頗相關。帖石防隤岸，開林出遠山。', '杜甫'), '杜甫'),
#  (('龜山有慰薦，南真為彌綸。玉管會玄圃，火棗承天姻。', '李商隱'), '杜甫'),
#  (('樽酒對不酌，默與玄相話。人生自不足，愛歎遭逢寡。', '杜牧'), '李白'),
#  (('眾芳信妍媚，威鳳難棲止。遂於鼙鼓間，移植東南美。', '劉禹錫'), '李白'),
#  (('飛湍瀑流爭喧豗，砯崖轉石萬壑雷。其險也如此，', '李白'), '李白'),
#  (('築室在人境，閉門無世喧。多君枉高駕，贈我以微言。', '李白'), '李白'),
#  (('燕雁迢迢隔上林，高秋望斷正長吟。人間路有潼江險，', '李商隱'), '杜甫'),
#  (('臥疾淹為客，蒙恩早廁儒。廷爭酬造化，樸直乞江湖。', '杜甫'), '杜甫'),
#  (('才子風流詠曉霞，倚樓吟住日初斜。', '杜牧'), '劉禹錫'),
#  (('塞路盡何處，我愁當落暉。終須接鴛鷺，霄漢共高飛。', '杜牧'), '杜甫'),
#  (('明主倘見收，煙霞路非賒。時命若不會，歸應煉丹砂。', '李白'), '李白'),
#  (('君不見秦時蜀太守，刻石立作三犀牛。自古雖有厭勝法，', '杜甫'), '杜甫'),
#  (('虛思黃金貴，自笑青雲期。長卿久病渴，武帝元同時。', '杜甫'), '杜甫'),
#  (('太華三芙蓉，明星玉女峰。尋仙下西嶽，陶令忽相逢。', '李白'), '李白'),
#  (('靈異可並跡，澹然與世閑。我來五松下，置酒窮躋攀。', '李白'), '李白'),
#  (('驕矜自言不可有，俠士堂中養來久。好鞍好馬乞與人，', '李白'), '李白'),
#  (('韓眾騎白鹿，西往華山中。玉女千餘人，相隨在雲空。', '李白'), '李白'),
#  (('笑出花間語，嬌來竹下歌。莫教明月去，留著醉嫦娥。', '李白'), '李白'),
#  (('我離雖則歲物改，如今了然失所在。別君莫道不盡歡，', '李白'), '李白'),
#  (('懶慢頭時櫛，艱難帶減圍。將軍猶汗馬，天子尚戎衣。', '杜甫'), '杜甫'),
#  (('初筵閱軍裝，羅列照廣庭。庭空六馬入，駊騀揚旗旌。', '杜甫'), '劉禹錫'),
#  (('綠鬢隨波散，紅顏逐浪無。', '李白'), '李白'),
#  (('新城非故里，終日想柴扃。興罷花還落，愁來酒欲醒。', '杜牧'), '杜甫'),
#  (('儒生老無成，臣子憂四番。篋中有舊筆，情至時複援。', '杜甫'), '杜甫'),
#  (('波濤無動勢，鱗介避餘威。會有知兵者，臨流指是非。', '劉禹錫'), '李商隱'),
#  (('屯田數十萬，堤防常懾惴。急征赴軍須，厚賦資凶器。', '杜牧'), '杜甫'),
#  (('下杜鄉園古，泉聲繞舍啼。靜思長慘切，薄宦與乖暌。', '杜牧'), '李商隱'),
#  (('如何一夢高唐雨，自此無心入武關。', '李商隱'), '杜牧'),
#  (('川光淨麥隴，日色明桑枝。訟息但長嘯，賓來或解頤。', '李白'), '李白'),
#  (('花徑逶迤柳巷深，小闌亭午囀春禽。', '李商隱'), '劉禹錫'),
#  (('影滅彩雲斷，遺聲落西秦。', '李白'), '李白'),
#  (('敬亭白雲氣，秀色連蒼梧。下映雙溪水，如天落鏡湖。', '李白'), '李白'),
#  (('香蘭愧傷暮，碧竹慚空中。可集呈瑞鳳，堪藏行雨龍。', '李商隱'), '李商隱'),
#  (('懷新目似擊，接要心已領。仿像識鮫人，空蒙辨魚艇。', '杜甫'), '杜甫'),
#  (('何人書破蒲葵扇，記著南塘移樹時。', '李商隱'), '李商隱'),
#  (('海燕參差溝水流，同君身世屬離憂。相攜花下非秦贅，', '李商隱'), '李白'),
#  (('猶賴德全如醉者，不妨吟詠入篇章。', '劉禹錫'), '杜牧'),
#  (('蓊匌川氣黃，群流會空曲。清晨望高浪，忽謂陰崖踣。', '杜甫'), '李白'),
#  (('賈傅松醪酒，秋來美更香。憐君片雲思，一去繞瀟湘。', '杜牧'), '李商隱'),
#  (('聞說江山好，憐君吏隱兼。寵行舟遠泛，怯別酒頻添。', '杜甫'), '杜甫'),
#  (('竹宮時望拜，桂館或求仙。姹女臨波日，神光照夜年。', '杜甫'), '劉禹錫'),
#  (('白日照舟師，朱旗散廣川。群公餞南伯，肅肅秩初筵。', '杜甫'), '杜甫'),
#  (('禁掖朋從改，微班性命全。青蒲甘受戮，白髮竟誰憐。', '杜甫'), '杜甫'),
#  (('得相能開國，生兒不象賢。淒涼蜀故妓，來舞魏宮前。', '劉禹錫'), '劉禹錫'),
#  (('空寄大羅天上事，眾仙同日詠霓裳。', '李商隱'), '李白'),
#  (('垂楊拂綠水，搖豔東風年。花明玉關雪，葉暖金窗煙。', '李白'), '李白'),
#  (('已去漢月遠，何時築城還。浮雲暮南征，可望不可攀。', '杜甫'), '李白'),
#  (('上黨爭為天下脊，邯鄲四十萬秦坑。狂童何者欲專地，', '杜牧'), '李商隱'),
#  (('輟棹青楓浦，雙楓舊已摧。自驚衰謝力，不道棟樑材。', '杜甫'), '杜甫'),
#  (('乘興但一行，且知我愛君。君來幾何時，仙台應有期。', '李白'), '李白'),
#  (('我向淮南攀桂枝，君留洛北愁夢思。不忍別，還相隨。', '李白'), '李白'),
#  (('患氣經時久，臨江卜宅新。喧卑方避俗，疏快頗宜人。', '杜甫'), '杜甫'),
#  (('君不見夔子之國杜陵翁，牙齒半落左耳聾。', '杜甫'), '杜甫'),
#  (('善知應觸類，各藉穎脫手。古來經濟才，何事獨罕有。', '杜甫'), '杜甫'),
#  (('孤雲隨殺氣，飛鳥避轅門。竟日留歡樂，城池未覺喧。', '杜甫'), '杜甫'),
#  (('曉樓煙檻出雲霄，景下林塘已寂寥。', '杜牧'), '劉禹錫'),
#  (('天下兵雖滿，春光日自濃。西京疲百戰，北闕任群凶。', '杜甫'), '杜甫'),
#  (('唯公出處得自在，決就放曠辭炎炎。座賓盡歡恣談謔，', '劉禹錫'), '杜甫'),
#  (('江行幾千里，海月十五圓。始經瞿塘峽，遂步巫山巔。', '李白'), '杜甫'),
#  (('故國還歸去，浮生亦可憐。高歌一曲淚，明日夕陽邊。', '杜牧'), '李白'),
#  (('披雲睹青天，捫虱話良圖。留侯將綺裏，出處未雲殊。', '李白'), '李白'),
#  (('野潤煙光薄，沙暄日色遲。客愁全為減，舍此複何之。', '杜甫'), '杜甫'),
#  (('以歡秦娥意，複得王母心。區區精衛鳥，銜木空哀吟。', '李白'), '杜甫'),
#  (('照秦通警急，過隴自艱難。聞道蓬萊殿，千門立馬看。', '杜甫'), '杜甫'),
#  (('古老向餘言，言是上留田，蓬科馬鬣今已平。', '李白'), '劉禹錫'),
#  (('瘧病餐巴水，瘡痍老蜀都。飄零迷哭處，天地日榛蕪。', '杜甫'), '杜甫'),
#  (('秋色何蒼然，際海俱澄鮮。山青滅遠樹，水綠無寒煙。', '李白'), '李白'),
#  (('皇穹竊恐不照余之忠誠，雷馮馮兮欲吼怒。', '李白'), '李白'),
#  (('北上何所苦，北上緣太行。磴道盤且峻，巉岩淩穹蒼。', '李白'), '李白'),
#  (('只雲徒有征，安能問無狀。一日五諸侯，奔亡如鳥往。', '杜牧'), '杜甫'),
#  (('猶有登朝舊冠冕，待公三入拂埃塵。', '劉禹錫'), '劉禹錫'),
#  (('誰人得似張公子，千首詩輕萬戶侯。', '杜牧'), '杜甫'),
#  (('有似山開萬里雲，四望青天解人悶。人悶還心悶，', '李白'), '李白'),
#  (('兩鬢入秋浦，一朝颯已衰。猿聲催白髮，長短盡成絲。', '李白'), '杜甫'),
#  (('無事坐悲苦，塊然涸轍魚。', '李白'), '杜甫'),
#  (('臨門送節制，以錫通天班。破者以族滅，存者尚遷延。', '李商隱'), '杜甫'),
#  (('故山迷白閣，秋水隱黃陂。不敢要佳句，愁來賦別離。', '杜甫'), '杜甫'),
#  (('脫略磻溪釣，操持郢匠斤。雲霄今已逼，台袞更誰親。', '杜甫'), '杜甫'),
#  (('王昌且在牆東住，未必金堂得免嫌。', '李商隱'), '李商隱'),
#  (('而我樂名山，對之心益閑。無論漱瓊液，還得洗塵顏。', '李白'), '李白'),
#  (('燕辭楓樹日，雁度麥城霜。空醉山翁酒，遙憐似葛強。', '杜甫'), '杜甫'),
#  (('少年曾醉酒旗下，同輩黃衣頷亦黃。蹴踏青雲尋入仕，', '劉禹錫'), '李商隱'),
#  (('禍轉亡胡歲，勢成擒胡月。胡命其能久，皇綱未宜絕。', '杜甫'), '杜甫'),
#  (('越王勾踐破吳歸，義士還鄉盡錦衣。', '李白'), '李白'),
#  (('商女不知亡國恨，隔江猶唱後庭花。', '杜牧'), '李商隱'),
#  (('高貲比封君，奇貨通幸卿。趨時鷙鳥思，藏鏹盤龍形。', '劉禹錫'), '劉禹錫'),
#  (('為我草真籙，天人慚妙工。七元洞豁落，八角輝星虹。', '李白'), '杜甫'),
#  (('紫駝之峰出翠釜，水精之盤行素鱗。犀箸厭飫久未下，', '杜甫'), '杜甫'),
#  (('隱者柴門內，畦蔬繞舍秋。盈筐承露薤，不待致書求。', '杜甫'), '杜甫'),
#  (('神仙有分豈關情，八馬虛隨落日行。', '李商隱'), '杜甫'),
#  (('長恨人心不如水，等閒平地起波瀾。', '劉禹錫'), '劉禹錫'),
#  (('仙公一奏思歸引，逐客初聞自泫然。', '劉禹錫'), '杜牧'),
#  (('猶期謝病後，共樂桑榆年。', '劉禹錫'), '杜牧'),
#  (('清秋幕府井梧寒，獨宿江城蠟炬殘。永夜角聲悲自語，', '杜甫'), '杜甫'),
#  (('干戈雖橫放，慘澹鬥龍蛇。甘澤不猶愈，且耕今未賒。', '杜甫'), '杜甫'),
#  (('如線如絲正牽恨，王孫歸路一何遙。', '李商隱'), '李商隱'),
#  (('家山見初月，林壑悄無塵。幽境此何夕，清光如為人。', '劉禹錫'), '李白'),
#  (('詞源倒流三峽水，筆陣獨掃千人軍。只今年才十六七，', '杜甫'), '杜甫'),
#  (('追餞同舟日，傷春一水間。飄零為客久，衰老羨君還。', '杜甫'), '杜甫'),
#  (('幾人全性命，盡室豈相偶。嶔岑猛虎場，鬱結回我首。', '杜甫'), '杜甫'),
#  (('青林虎丘寺，林際翠微路。立見山僧來，遙從鳥飛處。', '劉禹錫'), '劉禹錫'),
#  (('月峽瞿塘雲作頂，亂石崢嶸俗無井。雲安酤水奴僕悲，', '杜甫'), '杜甫'),
#  (('青冥亦自守，軟弱強扶持。味苦夏蟲避，叢卑春鳥疑。', '杜甫'), '杜甫'),
#  (('顧我蓬屋姿，謬通金閨籍。小來習性懶，晚節慵轉劇。', '杜甫'), '杜甫'),
#  (('明州長史外台郎，憶昔同年翰墨場。一自分襟多歲月，', '劉禹錫'), '劉禹錫'),
#  (('重過江南更千里，萬山深處一孤舟。', '杜牧'), '杜牧'),
#  (('賢哉四公子，撫掌黃泉裏。借問笑何人，笑人不好士。', '李白'), '李白'),
#  (('及此桑葉綠，春蠶起中閨。日出布穀鳴，田家擁鋤犁。', '李白'), '李白'),
#  (('定知欲報淮南詔，促召王褒入九重。', '劉禹錫'), '李商隱'),
#  (('汴水東流虎眼文，清淮曉色鴨頭春。', '劉禹錫'), '李白'),
#  (('叨陪錦帳座，久放白頭吟。反朴時難遇，忘機陸易沈。', '杜甫'), '杜甫'),
#  (('借問欲棲珠樹鶴，何年卻向帝城飛。', '李白'), '劉禹錫'),
#  (('博山爐中沉香火，雙咽一氣淩紫霞。', '李白'), '李白'),
#  (('虎丘山下劍池邊，長遣遊人歎逝川。罥樹斷絲悲舞席，', '李商隱'), '李白'),
#  (('賢良雖得祿，守道不封己。擁塞敗芝蘭，眾多盛荊杞。', '杜甫'), '杜甫'),
#  (('安得廣廈千萬間，大庇天下寒士俱歡顏，風雨不動安如山。', '杜甫'), '李白'),
#  (('攜手慚連璧，同心許斷金。紫芝雖繼唱，白雪少知音。——白居易', '劉禹錫'), '李商隱'),
#  (('有此傾城好顏色，天教晚發賽諸花。', '劉禹錫'), '杜甫'),
#  (('禁山開秘宇，複戶潔靈宅。蕊檢香氛氳，醮壇煙冪冪。', '劉禹錫'), '杜牧'),
#  (('池光忽隱牆，花氣亂侵房。屏緣蝶留粉，窗油蜂印黃。', '李商隱'), '李商隱'),
#  (('撫掌黃河曲，嗤嗤阮嗣宗。', '李白'), '李商隱'),
#  (('走平亂世相催促，一豁明主正郁陶。憶昔範增碎玉鬥，', '杜甫'), '杜甫'),
#  (('枚乘文章老，河間禮樂存。悲秋宋玉宅，失路武陵源。', '杜甫'), '杜甫'),
#  (('恐懼行裝數，伶俜臥疾頻。曉鶯工迸淚，秋月解傷神。', '杜甫'), '杜甫'),
#  (('楚星南天黑，蜀月西霧重。安得隨鳥翎，迫此懼將恐。', '杜甫'), '杜甫'),
#  (('樓船一舉風波靜，江漢翻為雁鶩池。', '李白'), '劉禹錫'),
#  (('載酒五松山，頹然白雲歌。中天度落月，萬里遙相過。', '李白'), '李白'),
#  (('遠謫年猶少，初歸鬢已衰。門閑故吏去，室靜老僧期。', '劉禹錫'), '劉禹錫'),
#  (('憔悴欲四十，無肉畏蚤虱。兒慎勿學爺，讀書求甲乙。', '李商隱'), '杜甫'),
#  (('將老憂貧窶，筋力豈能及。征途乃侵星，得使諸病入。', '杜甫'), '杜甫'),
#  (('握雪海上餐，拂沙隴頭寢。何當破月氏，然後方高枕。', '李白'), '李白'),
#  (('前榮後枯相翻覆，何惜餘光及棣華。', '李白'), '李白'),
#  (('茂苑城如畫，閶門瓦欲流。還依水光殿，更起月華樓。', '李商隱'), '杜甫'),
#  (('李杜齊名真忝竊，朔雲寒菊倍離憂。', '杜甫'), '杜甫'),
#  (('聞駐行春旆，中途賞物華。緣憂武昌柳，遂憶洛陽花。', '李商隱'), '劉禹錫'),
#  (('煙起藥廚晚，杵聲松院深。閑眠得真性，惆悵舊時心。', '杜牧'), '劉禹錫'),
#  (('此日此時人共得，一談一笑俗相看。尊前柏葉休隨酒，', '杜甫'), '李白'),
#  (('俗態雖多累，仙標發近狂。聲名佳句在，身世玉琴張。', '李商隱'), '杜牧'),
#  (('奮跡登弘閣，摧心對董帷。校讎如有暇，松竹一相思。', '李商隱'), '李白'),
#  (('華蓋垂下睫，嵩嶽臨上唇。不睹詭譎貌，豈知造化神。', '李白'), '李白'),
#  (('有懷非惜恨，不奈寸腸何。即席回彌久，前時斷固多。', '李商隱'), '杜甫'),
#  (('堅貞貫四候，標格殊百卉。歲晚當自知，繁華豈雲比。', '劉禹錫'), '杜甫'),
#  (('佇立東城隅，悵望高飛禽。草堂亂懸圃，不隔昆侖岑。', '杜甫'), '杜甫'),
#  (('瑤琴愔愔藏楚弄，越羅冷薄金泥重。簾鉤鸚鵡夜驚霜，', '李商隱'), '杜牧'),
#  (('盛氣光引爐煙，素草寒生玉佩。應是天仙狂醉，', '李白'), '劉禹錫'),
#  (('子孫存如線，舊客舟凝滯。君臣尚論兵，將帥接燕薊。', '杜甫'), '杜甫'),
#  (('驅馬天雨雪，軍行入高山。徑危抱寒石，指落曾冰間。', '杜甫'), '杜甫'),
#  (('待爾嗔烏鵲，拋書示鶺鴒。枝間喜不去，原上急曾經。', '杜甫'), '杜甫'),
#  (('猿嘯風中斷，漁歌月裏聞。閑隨白鷗去，沙上自為群。', '李白'), '李白'),
#  (('我來圯橋上，懷古欽英風。惟見碧流水，曾無黃石公。', '李白'), '李白'),
#  (('我宿五松下，寂寥無所歡。田家秋作苦，鄰女夜舂寒。', '李白'), '李白'),
#  (('帝子隔洞庭，青楓滿瀟湘。懷君路綿邈，覽古情淒涼。', '李白'), '杜甫'),
#  (('倦程山向背，望國闕嵯峨。故念飛書及，新歡借夢過。', '李商隱'), '李白'),
#  (('光縣與琴焦，旗亭無酒濡。市人委百貨，邑令遺雙鳧。', '劉禹錫'), '李白'),
#  (('非關宋玉有微辭，卻是襄王夢覺遲。', '李商隱'), '李商隱'),
#  (('過懶從衣結，頻游任履穿。藩籬無限景，恣意買江天。', '杜甫'), '杜甫'),
#  (('俗變羌胡語，人多沙塞顏。申包惟慟哭，七日鬢毛斑。', '李白'), '杜甫'),
#  (('淮王愛八公，攜手綠雲中。小子忝枝葉，亦攀丹桂叢。', '李白'), '李白'),
#  (('初登翠微嶺，複憩金沙泉。踐苔朝霜滑，弄波夕月圓。', '李白'), '李白'),
#  (('地擁金陵勢，城回江水流。當時百萬戶，夾道起朱樓。', '李白'), '李白'),
#  (('戀子四五人，裴回未翱翔。東流送白日，驟歌蘭蕙芳。', '李白'), '李白'),
#  (('月裏甯無姊，雲中亦有君。三清與仙島，何事亦離群。', '李商隱'), '李商隱'),
#  (('五月南風興，思君下巴陵。八月西風起，想君發揚子。', '李白'), '李白'),
#  (('竟與蛟螭雜，空聞燕雀喧。青冥猶契闊，陵厲不飛翻。', '杜甫'), '杜甫'),
#  (('因傾一樽酒，題作杜秋詩。愁來獨長詠，聊可以自怡。', '杜牧'), '李白'),
#  (('下視生物息，霏如隙中塵。醯雞仰甕口，亦謂雲漢津。', '劉禹錫'), '杜甫'),
#  (('客則掛冠至，交非傾蓋新。由來意氣合，直取性情真。', '杜甫'), '杜甫'),
#  (('圭臬星經奧，蟲篆丹青廣。子雲窺未遍，方朔諧太枉。', '杜甫'), '劉禹錫'),
#  (('湖闊兼雲霧，樓孤屬晚晴。禮加徐孺子，詩接謝宣城。', '杜甫'), '杜甫'),
#  (('昭君拂玉鞍，上馬啼紅頰。今日漢宮人，明朝胡地妾。', '李白'), '李白'),
#  (('中途偶良朋，問我將何行。欲獻濟時策，此心誰見明。', '李白'), '李白'),
#  (('漁舟何招招，浮在武陵水。拖綸擲餌信流去，', '劉禹錫'), '李白'),
#  (('西當太白有鳥道，可以橫絕峨眉顛。地崩山摧壯士死，', '李白'), '李白'),
#  (('芭蕉不展丁香結，同向春風各自愁。', '李商隱'), '杜甫'),
#  (('日月無偏照，何由訴蒼昊。良牧稱神明，深仁恤交道。', '李白'), '李白'),
#  (('不以千里遙，命駕來相招。中逢元丹丘，登嶺宴碧霄。', '李白'), '李白'),
#  (('把取菱花百煉鏡，換他竹葉十旬杯。嚬眉厭老終難去，', '劉禹錫'), '李白'),
#  (('帝問主人翁，有自賣珠兒。武昌昔男子，老苦為人妻。', '李商隱'), '杜甫'),
#  (('乘輿擁翠蓋，扈從金城東。寶馬麗絕景，錦衣入新豐。', '李白'), '杜甫'),
#  (('夢長銀漢落，覺罷天星稀。含悲想舊國，泣下誰能揮。', '李白'), '杜甫'),
#  (('鬥巧猴雕刺，誇趫索掛跟。狐威假白額，梟嘯得黃昏。', '杜牧'), '李白'),
#  (('暫別瑤墀鴛鷺行，彩旗雙引到沅湘。城邊流水桃花過，', '劉禹錫'), '劉禹錫'),
#  (('君看渡口淘沙處，渡卻人間多少人。', '劉禹錫'), '劉禹錫'),
#  (('雁矯銜蘆內，猿啼失木間。弊裘蘇季子，曆國未知還。', '杜甫'), '杜甫'),
#  (('君到臨邛問酒壚，近來還有長卿無。', '李商隱'), '劉禹錫'),
#  (('日落沙明天倒開，波搖石動水縈回。', '李白'), '李白'),
#  (('謝公莫道東山去，待取陰成滿鳳池。', '劉禹錫'), '李白'),
#  (('永嘉多北至，句漏且南征。必見公侯複，終聞盜賊平。', '杜甫'), '杜甫'),
#  (('別有歡娛處，承恩樂未窮。誰憐團扇妾，獨坐怨秋風。', '李白'), '李白'),
#  (('愛客尚書貴，之官宅相賢。——杜甫', '杜甫'), '杜甫'),
#  (('橫江西望阻西秦，漢水東連揚子津。', '李白'), '李白'),
#  (('連山似驚波，合遝出溟海。揚袂揮四座，酩酊安所知。', '李白'), '李白'),
#  (('雲間吟瓊簫，石上弄寶瑟。平生有微尚，歡笑自此畢。', '李白'), '李白'),
#  (('眾果莫相誚，天生名品高。何因古樂府，惟有鄭櫻桃。', '李商隱'), '李白'),
#  (('昨夜玉輪明，傳聞近太清。涼波沖碧瓦，曉暈落金莖。', '李商隱'), '劉禹錫'),
#  (('吳越古今路，滄波朝夕流。從來別離地，能使管弦愁。', '劉禹錫'), '李白'),
#  (('君開萬叢人，鞍馬皆辟易。告急清憲台，脫餘北門厄。', '李白'), '杜甫'),
#  (('戶外重陰黯不開，含羞迎夜複臨台。', '李商隱'), '劉禹錫'),
#  (('只言期一載，誰謂曆三秋。使妾腸欲斷，恨君情悠悠。', '李白'), '李商隱'),
#  (('曲盡酒亦傾，北窗醉如泥。人生且行樂，何必組與珪。', '李白'), '李白'),
#  (('腸斷未忍掃，眼穿仍欲歸。芳心向春盡，所得是沾衣。', '李商隱'), '李商隱'),
#  (('猶自保郎心似石，綾梭夜夜織寒衣。', '杜牧'), '劉禹錫'),
#  (('秋露白如玉，團團下庭綠。我行忽見之，寒早悲歲促。', '李白'), '劉禹錫'),
#  (('賦妙排鸚鵡，詩能繼鶺鴒。蒲親香案色，蘭動粉闈馨。', '杜牧'), '杜甫'),
#  (('慘澹風雲會，乘時各有人。力侔分社稷，志屈偃經綸。', '杜甫'), '杜甫'),
#  (('春風猶自疑聯句，雪絮相和飛不休。', '李商隱'), '李商隱'),
#  (('甘英窮西海，四萬到洛陽。東南我所見，北可計幽荒。', '杜牧'), '李白'),
#  (('蓬萊殿前諸主將，才如伏波不得驕。', '杜甫'), '杜甫'),
#  (('瞻光惜頹發，閱水悲徂年。北渚既蕩漾，東流自潺湲。', '李白'), '杜甫'),
#  (('披顏爭倩倩，逸足競駸駸。朗鑒存愚直，皇天實照臨。', '杜甫'), '李白'),
#  (('昔在南陽城，唯餐獨山蕨。憶與崔宗之，白水弄素月。', '李白'), '李白'),
#  (('綺羅錦繡段，有贈黃金千。十五許嫁君，二十移所天。', '李白'), '李白'),
#  (('燕體傷風力，雞香積露文。殷鮮一相雜，啼笑兩難分。', '李商隱'), '杜甫'),
#  (('北思驚沙雁，南情屬海禽。關山已搖落，天地共登臨。', '李商隱'), '劉禹錫'),
#  (('適知小閣還斜照，羨殺烏龍臥錦茵。', '李商隱'), '杜甫'),
#  (('長林偃風色，回復意猶迷。衫裛翠微潤，馬銜青草嘶。', '杜甫'), '杜甫'),
#  (('仰看日車側，俯恐坤軸弱。魑魅嘯有風，霜霰浩漠漠。', '杜甫'), '杜甫'),
#  (('不知桂樹在何處，仙人不下雙金莖。百尺相風插重屋，', '李商隱'), '李商隱'),
#  (('吾家白額駒，遠別臨東道。他日相思一夢君，', '李白'), '李白'),
#  (('因隳畫一法，且逐隨時利。流品極蒙尨，網羅漸離弛。', '杜牧'), '劉禹錫'),
#  (('玉蟾離海上，白露濕花時。雲畔風生爪，沙頭水浸眉。', '李白'), '李白'),
#  (('杜鵑花開春已闌，歸向陵陽釣魚晚。', '李白'), '劉禹錫'),
#  (('江閣嫌津柳，風帆數驛亭。應論十年事，愁絕始星星。', '杜甫'), '杜牧'),
#  (('天地為橐鑰，周流行太易。造化合元符，交媾騰精魄。', '李白'), '李白'),
#  (('崇文館裏丹霜後，無限紅梨憶校書。', '李商隱'), '劉禹錫'),
#  (('林密聞風遠，池平見月勻。藤龕紅婀娜，苔磴綠嶙峋。', '杜牧'), '杜牧'),
#  (('一經器物內，永掛粗刺痕。志士采紫芝，放歌避戎軒。', '杜甫'), '杜甫'),
#  (('武功少也孤，徒步客徐兗。讀書東嶽中，十載考墳典。', '杜甫'), '杜甫'),
#  (('瀟灑江湖十過秋，酒杯無日不淹留。謝公城畔溪驚夢，', '杜牧'), '李商隱'),
#  (('三年猶瘧疾，一鬼不銷亡。隔日搜脂髓，增寒抱雪霜。', '杜甫'), '李商隱'),
#  (('傳語風光共流轉，暫時相賞莫相違。', '杜甫'), '劉禹錫'),
#  (('隋朝大業末，房杜俱交友。長者來在門，荒年自糊口。', '杜甫'), '杜甫'),
#  (('明神司過豈令冤，暗室由來有禍門。', '李商隱'), '杜甫'),
#  (('樓高春日早，屏束麝煙堆。盼眄凝魂別，依稀夢雨來。', '杜牧'), '劉禹錫'),
#  (('天籟何參差，噫然大塊吹。玄元包橐鑰，紫氣何逶迤。', '李白'), '李白'),
#  (('昔賢多使氣，憂國不謀身。目覽千載事，心交上古人。', '劉禹錫'), '杜甫'),
#  (('五彩繡團圓，登君玳瑁筵。最宜紅燭下，偏稱落花前。', '劉禹錫'), '劉禹錫'),
#  (('暑退人體輕，雨餘天色改。荷珠貫索斷，竹粉殘妝在。', '劉禹錫'), '李商隱'),
#  (('懶從唐生決，羞訪季主蔔。四十九年非，一往不可複。', '李白'), '李白'),
#  (('玉露凋傷楓樹林，巫山巫峽氣蕭森。江間波浪兼天湧，', '杜甫'), '杜甫'),
#  (('帝力收三統，天威總四溟。舊都俄望幸，清廟肅惟馨。', '杜甫'), '杜甫'),
#  (('抱石恥獻玉，沉泉笑探珠。羽化如可作，相攜上清都。', '李白'), '李白'),
#  (('地下蘇司業，情親獨有君。那因喪亂後，便有死生分。', '杜甫'), '杜甫'),
#  (('秋水清無底，蕭然靜客心。掾曹乘逸興，鞍馬去相尋。', '杜甫'), '杜甫'),
#  (('兩都耆舊偏垂淚，臨老中原見朔風。', '李商隱'), '杜甫'),
#  (('皇都陸海應無數，忍剪淩雲一寸心。', '李商隱'), '李白'),
#  (('萬物有醜好，各一姿狀分。唯人即不爾，學與不學論。', '杜牧'), '李商隱'),
#  (('清時為丞郎，氣力侔陶鈞。乞取鬥升水，因之雲漢津。', '劉禹錫'), '劉禹錫'),
#  (('辟邪伎作鼓吹驚，雉子班之奏曲成，喔咿振迅欲飛鳴。', '李白'), '李白'),
#  (('上有青冥之長天，下有淥水之波瀾。天長路遠魂飛苦，', '李白'), '李白'),
#  (('莫言一片危基在，猶過無窮來往人。', '劉禹錫'), '杜牧'),
#  (('官忝趨棲鳳，朝回歎聚螢。喚人看騕褭，不嫁惜娉婷。', '杜甫'), '杜甫'),
#  (('葉動驚彩翰，波澄見赬首。晉宋齊梁都，千山萬江口。', '劉禹錫'), '杜甫'),
#  (('退朝還公府，騎吹息繁陰。吏散秋庭寂，烏啼煙樹深。', '劉禹錫'), '杜甫'),
#  (('浪跡江湖白髮新，浮雲一片是吾身。寒歸山觀隨棋局，', '李商隱'), '杜甫'),
#  (('青樓何所在，乃在碧雲中。寶鏡掛秋水，羅衣輕春風。', '李白'), '李白'),
#  (('水闊蒼梧野，天高白帝秋。途窮那免哭，身老不禁愁。', '杜甫'), '杜甫'),
#  (('憂來杖匣劍，更上林北岡。瘴毒猿鳥落，峽幹南日黃。', '杜甫'), '杜甫'),
#  (('襄陽行樂處，歌舞白銅鞮。江城回淥水，花月使人迷。', '李白'), '李白'),
#  (('關西賤男子，誓肉虜杯羹。請數系虜事，誰其為我聽。', '杜牧'), '杜甫'),
#  (('徐巿載秦女，樓船幾時回。但見三泉下，金棺葬寒灰。', '李白'), '杜甫'),
#  (('農務村村急，春流岸岸深。乾坤萬里眼，時序百年心。', '杜甫'), '杜甫'),
#  (('新豐綠樹起黃埃，數騎漁陽探使回。', '杜牧'), '劉禹錫'),
#  (('黃鵠去不息，哀鳴何所投。君看隨陽雁，各有稻粱謀。', '杜甫'), '李白'),
#  (('野亭逼湖水，歇馬高林間。鼉吼風奔浪，魚跳日映山。', '杜甫'), '杜甫'),
#  (('此邦俯要衝，實恐人事稠。應接非本性，登臨未銷憂。', '杜甫'), '杜甫'),
#  (('黃雀飽野粟，群飛動荊榛。今君抱何恨，寂寞向時人。', '杜甫'), '杜甫'),
#  (('謬題金閨籍，得與銀台通。待詔奉明主，抽毫頌清風。', '李白'), '杜甫'),
#  (('北斗不酌酒，南箕空簸揚。', '李白'), '李白'),
#  (('憂我營茅棟，攜錢過野橋。他鄉唯表弟，還往莫辭遙。', '杜甫'), '杜甫'),
#  (('鳳穴雛皆好，龍門客又新。義聲紛感激，敗績自逡巡。', '杜甫'), '杜甫'),
#  (('羈離暫愉悅，羸老反惆悵。中原未解兵，吾得終疏放。', '杜甫'), '杜甫'),
#  (('玉柱琤瑽韻，金觥雹凸棱。何時良宴會，促膝對華燈。', '劉禹錫'), '劉禹錫'),
#  (('燕趙有秀色，綺樓青雲端。眉目豔皎月，一笑傾城歡。', '李白'), '李白'),
#  (('潛魚不銜鉤，走鹿無反顧。皦皦幽曠心，拳拳異平素。', '杜甫'), '李白'),
#  (('雪耀冰霜冷，塵飛水墨昏。莫教垂露跡，歲晚雜苔痕。', '杜牧'), '杜甫'),
#  (('朝元閣迥羽衣新，首按昭陽第一人。', '李商隱'), '劉禹錫'),
#  (('安得秦吉了，為人道寸心。', '李白'), '李白'),
#  (('淚續淺深綆，腸危高下弦。紅顏無定所，得失在當年。', '李商隱'), '李商隱'),
#  (('楚山經月火，大旱則斯舉。舊俗燒蛟龍，驚惶致雷雨。', '杜甫'), '杜甫'),
#  (('寬心應是酒，遣興莫過詩。此意陶潛解，吾生後汝期。', '杜甫'), '杜甫'),
#  (('畏落日月後，強歡歌與酒。秋霜不惜人，倏忽侵蒲柳。', '李白'), '李白'),
#  (('下令蠲裏布，指期輕市租。閈垣適未立，苫蓋自相娛。', '劉禹錫'), '杜甫'),
#  (('高桃留晚實，尋得小庭南。矮墮綠雲髻，欹危紅玉簪。', '李商隱'), '李商隱'),
#  (('汲黯匡君切，廉頗出將頻。直詞才不世，雄略動如神。', '杜甫'), '杜甫'),
#  (('忽逢青雲士，共解丹霞裳。水退池上熱，風生松下涼。', '李白'), '李白'),
#  (('鸞車速風電，龍騎無鞭策。一舉上九天，相攜同所適。', '李白'), '李白'),
#  (('談笑三軍卻，交遊七貴疏。仍留一隻箭，未射魯連書。', '李白'), '李白'),
#  (('砧響家家發，樵聲個個同。飛霜任青女，賜被隔南宮。', '杜甫'), '杜甫'),
#  (('清猿斷人腸，遊子思故鄉。明發首東路，此歡焉可忘。', '李白'), '杜甫'),
#  (('於闐采花人，自言花相似。明妃一朝西入胡，', '李白'), '李白'),
#  (('恍恍與之去，駕鴻淩紫冥。俯視洛陽川，茫茫走胡兵。', '李白'), '李白'),
#  (('鉤陳摧徼道，槍櫐失儲胥。文物陪巡守，親賢病拮据。', '杜甫'), '杜甫'),
#  (('旋撲珠簾過粉牆，輕于柳絮重於霜。已隨江令誇瓊樹，', '李商隱'), '李商隱'),
#  (('人世死前唯有別，春風爭擬惜長條。', '李商隱'), '劉禹錫'),
#  (('雲裏相呼疾，沙邊自宿稀。系書元浪語，愁寂故山薇。', '杜甫'), '杜甫'),
#  (('發憤去函谷，從軍向臨洮。叱吒萬戰場，匈奴盡奔逃。', '李白'), '李白'),
#  (('八元邦族盛，萬石門風厚。天柱揭東溟，文星照北斗。', '劉禹錫'), '杜甫'),
#  (('紅旗閱五兵，絳帳領諸生。味道輕鼎食，退公猶筆耕。', '劉禹錫'), '杜甫'),
#  (('太和八九年，訓注極虓虎。潛身九地底，轉上青天去。', '杜牧'), '杜甫'),
#  (('人亡餘故宅，空有荷花生。念此杳如夢，淒然傷我情。', '李白'), '李白'),
#  (('接棹隋河溢，連蹄蜀棧刓。漉空滄海水，搜盡卓王孫。', '杜牧'), '杜甫'),
#  (('爾見山吏部，當應無陸沉。', '李白'), '劉禹錫'),
#  (('笑擊羊皮鼓，行牽犢頷車。中庭貪夜戲，不覺玉繩斜。', '劉禹錫'), '劉禹錫'),
#  (('高文會隋季，提劍徇天意。扶持萬代人，步驟三皇地。', '杜牧'), '杜牧'),
#  (('旌節下朝台，分圭從北回。城頭鶴立處，驛樹鳳棲來。', '劉禹錫'), '劉禹錫'),
#  (('丹禁虛東合，蒼生望北轅。徒令雙白鶴，五裏自翩翻。', '劉禹錫'), '杜甫'),
#  (('去去何足道，臨歧空複愁。肝膽不楚越，山河亦衾裯。', '李白'), '李白'),
#  (('朝雲夜入無行處，巴水橫天更不流。', '李白'), '李白'),
#  (('澤國雖勤雨，炎天竟淺泥。小江還積浪，弱纜且長堤。', '杜甫'), '杜甫'),
#  (('以茲謝朝列，長嘯歸故園。故園恣閒逸，求古散縹帙。', '李白'), '李白'),
#  (('比屋惸嫠輩，連年水旱並。遐思常後已，下令必先庚。', '劉禹錫'), '杜甫'),
#  (('岸柳兼池綠，園花映燭紅。未曾周顗醉，轉覺季心恭。', '李商隱'), '李商隱'),
#  (('直到綿州始分首，江邊樹裏共誰來。', '杜甫'), '杜牧'),
#  (('何如投水中，流落他人開。不惜他人開，但恐生是非。', '李白'), '李白'),
#  (('秀色一如此，多為眾女譏。君恩移昔愛，失寵秋風歸。', '李白'), '李白'),
#  (('後嶺有微雨，北窗生曉涼。徒勞問歸路，峰疊繞家鄉。', '杜牧'), '杜牧'),
#  (('嘉陵江色何所似，石黛碧玉相因依。正憐日破浪花出，', '杜甫'), '杜甫'),
#  (('突營射殺呼延將，獨領殘兵千騎歸。', '李白'), '李白'),
#  (('世人信耳目，方寸度大鈞。安知視聽外，怪愕不可陳。', '劉禹錫'), '杜甫'),
#  (('憑寄狂夫書一紙，家住成都萬里橋。', '劉禹錫'), '劉禹錫'),
#  (('鸕鷀窺淺井，蚯蚓上深堂。車馬何蕭索，門前百草長。', '杜甫'), '李白'),
#  (('忽爾弦斷絕，俄聞管參差。洛橋碧雲晚，西望佳人期。', '劉禹錫'), '劉禹錫'),
#  (('遠火微微辨，繁星歷歷看。茂先知味好，曼倩恨偷難。', '杜牧'), '劉禹錫'),
#  (('家本紫雲山，道風未淪落。沉懷丹丘志，沖賞歸寂寞。', '李白'), '李白'),
#  (('落日平臺上，春風啜茗時。石闌斜點筆，桐葉坐題詩。', '杜甫'), '劉禹錫'),
#  (('深處會容高尚者，水苗三頃百株桑。', '杜牧'), '杜甫'),
#  (('病妻尚在床，稚子初離乳。幽蘭思楚澤，恨水啼湘渚。', '杜牧'), '杜牧'),
#  (('迥見孤輪出，高從倚蓋旋。二儀含皎澈，萬象共澄鮮。', '劉禹錫'), '劉禹錫'),
#  (('玉觴淡無味，胡羯豈強敵。長歌激屋樑，淚下流衽席。', '杜甫'), '杜甫'),
#  (('日觀東北傾，兩崖夾雙石。海水落眼前，天光遙空碧。', '李白'), '李白'),
#  (('草閣柴扉星散居，浪翻江黑雨飛初。', '杜甫'), '杜甫'),
#  (('卓絕二道人，結交鳳與麟。行融亦俊發，吾知有英骨。', '李白'), '杜甫'),
#  (('豔彩凝還泛，清香絕複尋。光華童子佩，柔軟美人心。', '劉禹錫'), '杜甫'),
#  (('別家三月一得書，避地何時免愁苦。', '杜甫'), '李商隱'),
#  (('暖風遲日柳初含，顧影看身又自慚。', '杜牧'), '杜牧'),
#  (('十年一覺揚州夢，贏得青樓薄幸名。', '杜牧'), '李商隱'),
#  (('兩鬢蓬常亂，雙眸血不開。聖朝敦爾類，非獨路人哀。', '李商隱'), '杜甫'),
#  (('多士還魚貫，雲誰正駿奔。暫能誅倏忽，長與問乾坤。', '李商隱'), '杜甫'),
#  (('迥拂來鴻急，斜催別燕高。已寒休慘澹，更遠尚呼號。', '李商隱'), '杜甫'),
#  (('露寒風定不無情，臨水當山又隔城。', '李商隱'), '李商隱'),
#  (('虎睛珠絡褓，金盤犀鎮帷。長楊射熊羆，武帳弄啞咿。', '杜牧'), '杜牧'),
#  (('古來事反復，相見橫涕泗。向者玉珂人，誰是青雲器。', '杜甫'), '杜甫'),
#  (('詩律群公問，儒門舊史長。清秋便寓直，列宿頓輝光。', '杜甫'), '杜甫'),
#  (('諫官非不達，詩義早知名。破的由來事，先鋒孰敢爭。', '杜甫'), '杜牧'),
#  (('雨色風吹去，南行拂楚王。高丘懷宋玉，訪古一沾裳。', '李白'), '李白'),
#  (('清晨蒙菜把，常荷地主恩。守者愆實數，略有其名存。', '杜甫'), '杜甫'),
#  (('俄然素書及，解此長渴饑。策馬望山月，途窮造階墀。', '李白'), '李白'),
#  (('上有乘鸞女，蒼蒼蟲網遍。明年入懷袖，別是機中練。', '劉禹錫'), '劉禹錫'),
#  (('報韓雖不成，天地皆振動。潛匿遊下邳，豈曰非智勇。', '李白'), '李白'),
#  (('但識金馬門，誰知蓬萊山。白首死羅綺，笑歌無時閑。', '李白'), '李白'),
#  (('知君未愛春湖色，興在驪駒白玉珂。', '杜甫'), '李白'),
#  (('朱雀橋邊野草花，烏衣巷口夕陽斜。', '劉禹錫'), '劉禹錫'),
#  (('江湖凡馬多憔悴，衣冠往往乘蹇驢。梁公富貴於身疏，', '杜甫'), '杜甫'),
#  (('美人結長想，對此心淒然。攀條折春色，遠寄龍庭前。', '李白'), '李白'),
#  (('洗然順所適，此足代加餐。寂無斤斧響，庶遂憩息歡。', '杜甫'), '杜甫'),
#  (('黃閣長司諫，丹墀有故人。向來論社稷，為話涕沾巾。', '杜甫'), '杜甫'),
#  (('西京安穩未，不見一人來。臘日巴江曲，山花已自開。', '杜甫'), '杜甫'),
#  (('躍馬二十年，恐辜明主恩。坐見幽州騎，長驅河洛昏。', '杜甫'), '杜甫'),
#  (('開魚得錦字，歸問我何如。江山雖道阻，意合不為殊。', '李白'), '杜甫'),
#  (('問我將何事，湍波曆幾重。貂裘非季子，鶴氅似王恭。', '李白'), '李白'),
#  (('百川氣勢苦豪俊，坤關密鎖愁開張。太和六年亦如此，', '杜牧'), '杜甫'),
#  (('故人憂見及，此別淚相忘。各逐萍流轉，來書細作行。', '杜甫'), '杜甫'),
#  (('是時正忘戰，重兵多在邊。列城繞長河，平明插旗幡。', '李商隱'), '劉禹錫'),
#  (('盲風扇其威，白晝曛陽烏。操綆不暇汲，循牆還避逾。', '劉禹錫'), '杜甫'),
#  (('早忝金馬客，晚為商洛翁。知名四海內，多病一生中。', '劉禹錫'), '劉禹錫'),
#  (('士卒既輯睦，啟行促精悍。似聞上游兵，稍逼長沙館。', '杜甫'), '杜甫'),
#  (('晴暖感餘芳，紅苞雜絳房。落時猶自舞，掃後更聞香。', '李商隱'), '李商隱'),
#  (('依沙宿舸船，石瀨月娟娟。風起春燈亂，江鳴夜雨懸。', '杜甫'), '杜甫'),
#  (('久辭龍闕擁紅旗，喜見天顏拜赤墀。三省英寮非舊侶，', '劉禹錫'), '劉禹錫'),
#  (('如今雖在卞和手，□□正憔悴，了了知之亦何益。', '李白'), '李白'),
#  (('開州入夏知涼冷，不似雲安毒熱新。', '杜甫'), '杜甫'),
#  (('如何干鬥氣，竟作炎荒土。題此涕滋筆，以代投湘賦。', '杜牧'), '杜甫'),
#  (('蕭曹安zj屼，耿賈摧欃槍。吾家有季父，傑出聖代英。', '李白'), '李白'),
#  (('鴛鴦可羨頭俱白，飛去飛來煙雨秋。', '李商隱'), '杜牧'),
#  (('立神扶棟樑，鑿翠開戶牖。其陽產靈芝，其陰宿牛鬥。', '杜甫'), '劉禹錫'),
#  (('可憐留著臨江宅，異代應教庾信居。', '李商隱'), '杜甫'),
#  (('側聞夜來寇，幸喜囊中淨。艱危作遠客，幹請傷直性。', '杜甫'), '杜甫'),
#  (('去水絕還波，泄雲無定姿。人生在世間，聚散亦暫時。', '杜甫'), '李白'),
#  (('谷虛雲氣薄，波亂日華遲。戰伐何由定，哀傷不在茲。', '杜甫'), '杜甫'),
#  (('先朝納諫諍，直氣橫乾坤。子建文筆壯，河間經術存。', '杜甫'), '杜甫'),
#  (('明湖思曉月，疊嶂憶清猿。何由返初服，田野醉芳樽。', '李白'), '李白'),
#  (('樓高碧海出，樹古青蘿懸。光祿紫霞杯，伊昔忝相傳。', '李白'), '李白'),
#  (('圓荷想自昔，遺堞感至今。芳宴此時具，哀絲千古心。', '杜甫'), '杜甫'),
#  (('若信貝多真實語，三生同聽一樓鐘。', '李商隱'), '李商隱'),
#  (('顏回竟短折，賈誼徒忠貞。飛旐出江漢，孤舟輕荊衡。', '杜甫'), '杜甫'),
#  (('小鼎煎茶面曲池，白須道士竹間棋。', '李商隱'), '杜甫'),
#  (('黔陽信使應稀少，莫怪頻頻勸酒杯。', '杜甫'), '劉禹錫'),
#  (('攬彼造化力，持為我神通。晚謁泰山君，親見日沒雲。', '李白'), '李白'),
#  (('細草稱偏坐，香醪懶再酤。醉歸應犯夜，可怕李金吾。', '杜甫'), '杜甫'),
#  (('昭君拂玉鞍，上馬啼紅頰。今日漢宮人，明朝胡地妾。', '李白'), '李白'),
#  (('貢喜音容間，馮招病疾纏。南過駭倉卒，北思悄聯綿。', '杜甫'), '杜甫'),
#  (('蜀僧抱綠綺，西下峨眉峰。為我一揮手，如聽萬壑松。', '李白'), '李白'),
#  (('仙家一出尋無蹤，至今流水山重重。', '劉禹錫'), '劉禹錫'),
#  (('個裏愁人腸自斷，由來不是此聲悲。', '劉禹錫'), '杜牧'),
#  (('為之立長檠，布濩當軒綠。米液溉其根，理疏看滲漉。', '劉禹錫'), '杜甫'),
#  (('青雲少年子，挾彈章台左。鞍馬四邊開，突如流星過。', '李白'), '杜甫'),
#  (('無貴賤不悲，無富貧亦足。萬古一骸骨，鄰家遞歌哭。', '杜甫'), '杜甫'),
#  (('衣冠照雲日，朝下散皇州。鞍馬如飛龍，黃金絡馬頭。', '李白'), '李白'),
#  (('長安壯兒不敢騎，走過掣電傾城知。青絲絡頭為君老，', '杜甫'), '杜甫'),
#  (('堯舜當之亦禪禹。君失臣兮龍為魚，權歸臣兮鼠變虎。', '李白'), '杜牧'),
#  (('一院春草長，三山歸路迷。主人朝謁早，貪養汝南雞。', '劉禹錫'), '劉禹錫'),
#  (('韶嫩冰後木，輕盈煙際林。藤生欲有托，柳弱不自任。', '劉禹錫'), '李商隱'),
#  (('欹帆側柁入波濤，撇漩捎濆無險阻。朝發白帝暮江陵，', '杜甫'), '杜甫'),
#  (('田家望望惜雨幹，布穀處處催春種。淇上健兒歸莫懶，', '杜甫'), '劉禹錫'),
#  (('歌榭白團扇，舞筵金縷衫。旌旗遙一簇，舄履近相攙。', '劉禹錫'), '劉禹錫'),
#  (('長嘯梁甫吟，何時見陽春。君不見朝歌屠叟辭棘津，', '李白'), '李白'),
#  (('親知天畔少，藥味峽中無。歸楫生衣臥，春鷗洗翅呼。', '杜甫'), '杜甫'),
#  (('帝曰大布衣，藉卿佐元帥。坐看清流沙，所以子奉使。', '杜甫'), '李白'),
#  (('出舞兩美人，飄颻若雲仙。留歡不知疲，清曉方來旋。', '李白'), '李白'),
#  (('雲裏不聞雙雁過，掌中貪見一珠新。', '杜甫'), '劉禹錫'),
#  (('天邊老人歸未得，日暮東臨大江哭。隴右河源不種田，', '杜甫'), '杜甫'),
#  (('霸氣西南歇，雄圖歷數屯。錦江元過楚，劍閣複通秦。', '杜甫'), '杜甫'),
#  (('江南為客正悲秋，更送吾師古渡頭。', '杜牧'), '杜甫'),
#  (('朔雪落吳天，從風渡溟渤。海樹成陽春，江沙浩明月。', '李白'), '李白'),
#  (('外壘曾無警，中廚亦罷監。推誠人自服，去殺令逾嚴。', '劉禹錫'), '杜甫'),
#  (('祖龍浮海不成橋，漢武尋陽空射蛟。', '李白'), '李白'),
#  (('皓月方離海，堅冰正滿池。金波雙激射，璧彩兩參差。', '李商隱'), '李白'),
#  (('東海有勇婦，何慚蘇子卿。學劍越處子，超然若流星。', '李白'), '李白'),
#  (('近來豈少征人婦，笑采蘼蕪上北山。', '劉禹錫'), '杜甫'),
#  (('已老無時疾，長貧望歲登。雀羅秋寂寂，蟲翅曉薨薨。', '劉禹錫'), '杜甫'),
#  (('山鬼吹燈滅，廚人語夜闌。雞鳴問前館，世亂敢求安。', '杜甫'), '杜甫'),
#  (('閱景無旦夕，憑闌有今古。留我酒一樽，前山看春雨。', '杜牧'), '劉禹錫'),
#  (('萬乘慎出入，柏人以為識。', '李白'), '李白'),
#  (('使者分王命，群公各典司。恐乖均賦斂，不似問瘡痍。', '杜甫'), '杜甫'),
#  (('早忝登三署，曾聞奏六英。無能甘負弩，不慎在提衡。', '劉禹錫'), '劉禹錫'),
#  (('怪君近日文鋒利，新向延平看劍來。', '劉禹錫'), '劉禹錫'),
#  (('分憂餘刃又從公，白羽胡床嘯詠中。彩筆諭戎矜倚馬，', '劉禹錫'), '杜甫'),
#  (('生常免租稅，名不隸征伐。撫跡猶酸辛，平人固騷屑。', '杜甫'), '杜甫'),
#  (('對酒不肯飲，含情欲誰待。', '李白'), '李白'),
#  (('長幹吳兒女，眉目豔新月。屐上足如霜，不著鴉頭襪。', '李白'), '李白'),
#  (('詞臣陪羽獵，戰將騁騏驎。兩地差池恨，江汀醉送君。', '杜牧'), '杜牧'),
#  (('安得自西極，申命空山東。盡驅詣闕下，士庶塞關中。', '杜甫'), '杜甫'),
#  (('畫角悲海月，征衣卷天霜。揮刃斬樓蘭，彎弓射賢王。', '李白'), '李白'),
#  (('黃四娘家花滿蹊，千朵萬朵壓枝低。', '杜甫'), '李商隱'),
#  (('今日聽君歌一曲，暫憑杯酒長精神。', '劉禹錫'), '劉禹錫'),
#  (('天子昔避狄，與君亦乘驄。擁兵五陵下，長策遏胡戎。', '李白'), '杜甫'),
#  (('廄馬翩翩禁外逢，星槎上漢杳難從。', '劉禹錫'), '杜甫'),
#  (('竹徑縈紆入，花林委曲巡。斜陽眾客散，空鎖一園春。', '劉禹錫'), '劉禹錫'),
#  (('洛陽城裏多池館，幾處花開有主人。', '劉禹錫'), '劉禹錫'),
#  (('渚宮楊柳暗，麥城朝雉飛。可憐踏青伴，乘暖著輕衣。', '劉禹錫'), '劉禹錫'),
#  (('悶為洛生詠，醉發吳越調。赤霞動金光，日足森海嶠。', '李白'), '李白'),
#  (('指顧動白日，暖熱回蒼旻。公卿辱嘲叱，唾棄如糞丸。', '李商隱'), '杜甫'),
#  (('旌旆忽東下，笙歌隨舳艫。霜凋謝樓樹，沙暖句溪蒲。', '杜牧'), '杜甫'),
#  (('渡頭輕雨灑寒梅，雲際溶溶雪水來。夢渚草長迷楚望，', '劉禹錫'), '劉禹錫'),
#  (('玉質隨月滿，豔態逐春舒。絳唇漸輕巧，雲步轉虛徐。', '杜牧'), '杜甫'),
#  (('覺來盼庭前，一鳥花間鳴。借問此何時，春風語流鶯。', '李白'), '李白'),
#  (('鳳翣擁銘旌，威遲異吉行。漢儀陳秘器，楚挽咽繁聲。', '劉禹錫'), '杜甫'),
#  (('人豈無端別，猿應有意哀。征南予更遠，吟斷望鄉台。', '李商隱'), '李商隱'),
#  (('交合丹青地，恩傾雨露辰。有儒愁餓死，早晚報平津。', '杜甫'), '杜甫'),
#  (('遙作時多難，先令禍有源。初驚逐客議，旋駭黨人冤。', '李商隱'), '杜甫'),
#  (('得疾還因倚少年。天上別歸京兆府，人間空數茂陵阡。', '劉禹錫'), '劉禹錫'),
#  (('禦陌青門拂地垂，千條金縷萬條絲。', '劉禹錫'), '杜牧'),
#  (('破塊數席間，荷鋤功易止。兩旬不甲坼，空惜埋泥滓。', '杜甫'), '杜甫'),
#  (('影占徘徊處，光含的皪時。高低連素色，上下接清規。', '李商隱'), '劉禹錫'),
#  (('潼關地接古弘農，萬里高飛雁與鴻。桂樹一枝當白日，', '李商隱'), '李商隱'),
#  (('重陽獨酌杯中酒，抱病起登江上臺。竹葉於人既無分，', '杜甫'), '劉禹錫'),
#  (('瘴癘浮三蜀，風雲暗百蠻。捲簾唯白水，隱幾亦青山。', '杜甫'), '杜甫'),
#  (('晚醉題詩贈物華，罷吟還醉忘歸家。', '李商隱'), '李商隱'),
#  (('我是夢中傳彩筆，欲書花葉寄朝雲。', '李商隱'), '李商隱'),
#  (('中夜窟宅改，移因風雨秋。倒懸瑤池影，屈注蒼江流。', '杜甫'), '劉禹錫'),
#  (('誰謂朝來不作意，狂風挽斷最長條。', '杜甫'), '李商隱'),
#  (('南船正東風，北船來自緩。江上相逢借問君，', '李白'), '杜甫'),
#  (('種松夾石道，紆組臨沙阜。目覽帝王州，心存股肱守。', '劉禹錫'), '李白'),
#  (('稍促高高燕，微疏的的螢。故園煙草色，仍近五門青。', '李商隱'), '杜牧'),
#  (('方當節鉞用，必絕祲沴根。吾病日回首，雲台誰再論。', '杜甫'), '杜甫'),
#  (('我似鷓鴣鳥，南遷懶北飛。時尋漢陽令，取醉月中歸。', '李白'), '李白'),
#  (('綴席茱萸好，浮舟菡萏衰。季秋時欲半，九日意兼悲。', '杜甫'), '杜甫'),
#  (('何鄉為樂土，安敢尚盤桓。棄絕蓬室居，塌然摧肺肝。', '杜甫'), '杜甫'),
#  (('船舷不重扣，埋沒已經秋。仰看西飛翼，下愧東逝流。', '杜甫'), '杜甫'),
#  (('蕭蕭山路窮秋雨，淅淅溪風一岸蒲。', '杜牧'), '杜甫'),
#  (('公生揚馬後，名與日月懸。同游英俊人，多秉輔佐權。', '杜甫'), '李白'),
#  (('桃滿西園淑景催，幾多紅豔淺深開。', '杜牧'), '劉禹錫'),
#  (('好風初婉軟，離思苦縈盈。金馬舊遊貴，桐廬春水生。', '杜牧'), '劉禹錫'),
#  (('白雪關山遠，黃雲海戍迷。揮鞭萬里去，安得念春閨。', '李白'), '李白'),
#  (('麥隴和風吹樹枝，商山逸客出關時。身無拘束起長晚，', '劉禹錫'), '杜甫'),
#  (('故國思如此，若為天外心。', '劉禹錫'), '杜牧'),
#  (('的的新添恨，迢迢絕好音。文園終病渴，休詠白頭吟。', '杜牧'), '杜牧'),
#  (('池台樂事盡，簫鼓葬儀雄。一代英豪氣，曉散白楊風。', '劉禹錫'), '劉禹錫'),
#  (('東海橫秦望，西陵繞越台。湖清霜鏡曉，濤白雪山來。', '李白'), '李白'),
#  (('使君四十四，兩佩左銅魚。為吏非循吏，論書讀底書。', '杜牧'), '劉禹錫'),
#  (('遂有山陽作，多慚鮑叔知。素交零落盡，白首淚雙垂。', '杜甫'), '李白'),
#  (('舉袖露條脫，招我飯胡麻。', '李白'), '李白'),
#  (('憑寄狂夫書一紙，住在成都萬里橋。', '劉禹錫'), '劉禹錫'),
#  (('桃源人家易制度，橘洲田土仍膏腴。潭府邑中甚淳古，', '杜甫'), '劉禹錫'),
#  (('九重深處無人見，分付新聲與順郎。', '劉禹錫'), '劉禹錫'),
#  (('西憶故人不可見，東風吹夢到長安。寧期此地忽相遇，', '李白'), '李白'),
#  (('中原消息斷，黃屋今安否。終作適荊蠻，安排用莊叟。', '杜甫'), '杜甫'),
#  (('鬥雞初賜錦，舞馬既登床。簾下宮人出，樓前禦柳長。', '杜甫'), '劉禹錫'),
#  (('何慚宓子賤，不減陶淵明。吾知千載後，卻掩二賢名。', '李白'), '李白'),
#  (('不須並礙東西路，哭殺廚頭阮步兵。', '李商隱'), '杜甫'),
#  (('賢人有素業，乃在沙塘陂。竹影掃秋月，荷衣落古池。', '李白'), '李白'),
#  (('安得此相謂，欲慰衰朽質。青春妍和月，朋戲渾甥侄。', '李商隱'), '杜甫'),
#  (('執袂還應立馬看，向來離思始知難。', '杜牧'), '劉禹錫'),
#  (('牢落西江外，參差北戶間。久游巴子國，臥病楚人山。', '杜甫'), '杜甫'),
#  (('落景轉疏雨，晴雲散遠空。名山發佳興，清賞亦何窮。', '李白'), '杜甫'),
#  (('月光欲到長門殿，別作深宮一段愁。', '李白'), '李商隱'),
#  (('省郎憂病士，書信有柴胡。飲子頻通汗，懷君想報珠。', '杜甫'), '杜甫'),
#  (('長安布衣誰比數，反鎖衡門守環堵。老夫不出長蓬蒿，', '杜甫'), '杜甫'),
#  (('僕臥香爐頂，餐霞漱瑤泉。門開九江轉，枕下五湖連。', '李白'), '杜甫'),
#  (('雪中東郭履，堂上老萊衣。讀遍先賢傳，如君事者稀。', '李商隱'), '杜甫'),
#  (('大角纏兵氣，鉤陳出帝畿。煙塵昏禦道，耆舊把天衣。', '杜甫'), '劉禹錫'),
#  (('時人欲識胸襟否，彭蠡秋連萬里江。', '杜牧'), '杜甫'),
#  (('此情不可道，此別何時遇。望望不見君，連山起煙霧。', '李白'), '李白'),
#  (('心以當竹實，炯然無外求。血以當醴泉，豈徒比清流。', '杜甫'), '杜甫'),
#  (('此行疊壯觀，郭薛俱才賢。不知百載後，誰複來通泉。', '杜甫'), '杜甫'),
#  (('濁酒銷殘漏，弦聲間遠砧。酡顏舞長袖，密坐接華簪。——白居易', '劉禹錫'), '劉禹錫'),
#  (('江上日多雨，蕭蕭荊楚秋。高風下木葉，永夜攬貂裘。', '杜甫'), '杜甫'),
#  (('青雲馬生角，黃州使持節。秦嶺望樊川，只得回頭別。', '杜牧'), '杜甫'),
#  (('月暈天風霧不開，海鯨東蹙百川回。', '李白'), '李白'),
#  (('所冀旄頭滅，功成追魯連。', '李白'), '李白'),
#  (('淮山桂偃蹇，蜀郡桑重童。枝條亮眇脆，靈氣何由同。', '李商隱'), '劉禹錫'),
#  (('妻子寄他食，園林非昔遊。空餘繐帷在，淅淅野風秋。', '杜甫'), '杜甫'),
#  (('去夢隨川後，來風貯石郵。蘭叢銜露重，榆莢點星稠。', '李商隱'), '杜牧'),
#  (('整禦當西陸，舒光麗上玄。從星變風雨，順日助陶甄。', '劉禹錫'), '劉禹錫'),
#  (('鸞鳳戲三島，神仙居十洲。應憐萱草淡，卻得號忘憂。', '李商隱'), '劉禹錫'),
#  (('顧我如有情，長鳴似相托。何當駕此物，與爾騰寥廓。', '李白'), '李白'),
#  (('跨馬出郊時極目，不堪人事日蕭條。', '杜甫'), '杜甫'),
#  (('快意且為樂，列筵坐群公。光景不可留，生世如轉蓬。', '李白'), '李白'),
#  (('小隱慕安石，遠遊學屈平。天書訪江海，雲臥起咸京。', '李白'), '李白'),
#  (('晉庫走龍劍，吳宮傷燕雛。五行有沴氣，先哲垂籲謨。', '劉禹錫'), '杜甫'),
#  (('大鵬一日同風起，摶搖直上九萬里。假令風歇時下來，', '李白'), '劉禹錫'),
#  (('傅說版築臣，李斯鷹犬人。欻起匡社稷，甯複長艱辛。', '李白'), '杜甫'),
#  (('曙色未昭晰，露華遙斐舋。浩爾神骨清，如觀混元始。', '劉禹錫'), '李白'),
#  (('峽險風煙僻，天寒橘柚垂。築場看斂積，一學楚人為。', '杜甫'), '杜甫'),
#  (('藥物秘海嶽，采鉛青溪濱。時登大樓山，舉手望仙真。', '李白'), '李白'),
#  (('洛橋風暖細翻衣，春引仙官去玉墀。獨鶴初沖太虛日，', '杜牧'), '劉禹錫'),
#  (('瑤簡被靈誥，持符開七門。金鈴攝群魔，絳節何兟兟。', '李商隱'), '劉禹錫'),
#  (('昔別黃鶴樓，蹉跎淮海秋。俱飄零落葉，各散洞庭流。', '李白'), '李白'),
#  (('唯見芙蓉含曉露，數行紅淚滴清池。', '劉禹錫'), '李商隱'),
#  (('白馬小兒誰家子，泰清之歲來關囚。金陵昔時何壯哉，', '李白'), '李白'),
#  (('重關曉度宿雲寒，羸馬緣知步步難。', '杜牧'), '劉禹錫'),
#  (('乃言本蜀士，世降岷山靈。前人秉藝文，高視來上京。', '劉禹錫'), '劉禹錫'),
#  (('龍臥池猶在，鶯遷谷尚存。昔為揚子宅，今是李膺門。', '杜牧'), '杜甫'),
#  (('南嶽自茲近，湘流東逝深。和風引桂楫，春日漲雲岑。', '杜甫'), '杜甫'),
#  (('翅在雲天終不遠，力微矰繳絕須防。', '杜甫'), '杜甫'),
#  (('結實苦遲為人笑，攀折唧唧長咨嗟。', '李白'), '李白'),
#  (('歸來使酒氣，未肯拜蕭曹。羞入原憲室，荒徑隱蓬蒿。', '李白'), '杜甫'),
#  (('靡靡度行人，溫風吹宿麥。', '劉禹錫'), '李白'),
#  (('誰寄方隅理，朝難將帥權。春秋褒貶例，名器重雙全。', '杜甫'), '杜甫'),
#  (('日暮岸幘歸，傳呼隘阡陌。彤襜雙白鹿，賓從何輝赫。', '李白'), '杜甫'),
#  (('懶搖白羽扇，裸體青林中。脫巾掛石壁，露頂灑松風。', '李白'), '杜甫'),
#  (('連山蟠其間，溟漲與筆力。有練實先書，臨池真盡墨。', '杜甫'), '杜甫'),
#  (('行到中庭數花朵，蜻蜓飛上玉搔頭。', '劉禹錫'), '劉禹錫'),
#  (('曉戰隨金鼓，宵眠抱玉鞍。願將腰下劍，直為斬樓蘭。', '李白'), '李白'),
#  (('共說總戎雲鳥陣，不妨遊子芰荷衣。', '杜甫'), '杜甫'),
#  (('草閣臨無地，柴扉永不關。魚龍回夜水，星月動秋山。', '杜甫'), '杜甫'),
#  (('單于寇我壘，百里風塵昏。雄劍四五動，彼軍為我奔。', '杜甫'), '杜甫'),
#  (('朝弄紫沂海，夕披丹霞裳。揮手折若木，拂此西日光。', '李白'), '李白'),
#  (('憐我老病贈兩莖，出入爪甲鏗有聲。老夫複欲東南征，', '杜甫'), '杜甫'),
#  (('白帝城中雲出門，白帝城下雨翻盆。高江急峽雷霆鬥，', '杜甫'), '杜甫'),
#  (('雲物不殊鄉國異，教兒且覆掌中杯。', '杜甫'), '李商隱'),
#  (('吾聞聰明主，治國用輕刑。銷兵鑄農器，今古歲方寧。', '杜甫'), '杜甫'),
#  (('道北馮都使，高齋見一川。子能渠細石，吾亦沼清泉。', '杜甫'), '杜甫'),
#  (('在今氣磊落，巧偽莫敢親。介立實吾弟，濟時肯殺身。', '杜甫'), '杜甫'),
#  (('蜀將分旗鼓，羌兵助井泉。西戎背和好，殺氣日相纏。', '杜甫'), '杜甫'),
#  (('白石蓮花誰所共，六時長捧佛前燈。空庭苔蘚饒霜露，', '李商隱'), '李白'),
#  (('逡巡又過瀟湘雨，雨打湘靈五十弦。瞥見馮夷殊悵望，', '李商隱'), '杜牧'),
#  (('長安冬菹酸且綠，金城土酥靜如練。兼求富豪且割鮮，', '杜甫'), '李商隱'),
#  (('抱甕灌秋蔬，心閒遊天雲。每將瓜田叟，耕種漢水濆。', '李白'), '李白'),
#  (('醜女來效顰，還家驚四鄰。壽陵失本步，笑殺邯鄲人。', '李白'), '李白'),
#  (('漢北豺狼滿，巴西道路難。血埋諸將甲，骨斷使臣鞍。', '杜甫'), '杜甫'),
#  (('鞭屍辱已及，堂上羅宿莽。頗似今之人，蟊賊陷忠讜。', '李白'), '杜甫'),
#  (('尋常相見意殷勤，別後相思夢更頻。', '劉禹錫'), '李商隱'),
#  (('高僧拂玉柄，童子獻霜梨。惜去愛佳景，煙蘿欲暝時。', '李白'), '李白'),
#  (('高松來好月，空穀宜清秋。溪深古雪在，石斷寒泉流。', '李白'), '李白'),
#  (('一樽中夜酒，半破前峰月。煙院松飄蕭，風廊竹交戛。', '杜牧'), '杜牧'),
#  (('功成謝人間，從此一投釣。', '李白'), '李白'),
#  (('枉沐旌麾出城府，草茅無徑欲教鋤。', '杜甫'), '杜甫'),
#  (('大道如青天，我獨不得出。羞逐長安社中兒，', '李白'), '李白'),
#  (('青山橫北郭，白水繞東城。此地一為別，孤蓬萬里征。', '李白'), '杜甫'),
#  (('羅袖灑赤血，英聲淩紫霞。直上西山去，關吏相邀遮。', '李白'), '李白'),
#  (('玉樹春歸日，金宮樂事多。後庭朝未入，輕輦夜相過。', '李白'), '李白'),
#  (('吾曾弄海水，清淺嗟三變。果愜麻姑言，時光速流電。', '李白'), '李白'),
#  (('奮飛既胡越，局促傷樊籠。一飯四五起，憑軒心力窮。', '杜甫'), '李白'),
#  (('方丈三韓外，昆侖萬國西。建標天地闊，詣絕古今迷。', '杜甫'), '杜甫'),
#  (('誰人為報故交道，莫惜鯉魚時一雙。', '李商隱'), '杜牧'),
#  (('呼我遊太素，玉杯賜瓊漿。一餐曆萬歲，何用還故鄉。', '李白'), '李白'),
#  (('冬至至後日初長，遠在劍南思洛陽。青袍白馬有何意，', '杜甫'), '杜甫'),
#  (('徒侶問新事，煙雲愴別情。應誇乞食處，踏遍鳳凰城。', '劉禹錫'), '劉禹錫'),
#  (('氣劘屈賈壘，目短曹劉牆。忤下考功第，獨辭京尹堂。', '杜甫'), '杜甫'),
#  (('城烏啼眇眇，野鷺宿娟娟。皓首江湖客，鉤簾獨未眠。', '杜甫'), '杜甫'),
#  (('繁霜一夜相撩治，不似佳人似老人。', '劉禹錫'), '劉禹錫'),
#  (('鳳女彈瑤瑟，龍孫撼玉珂。京華他夜夢，好好寄雲波。', '李商隱'), '李商隱'),
#  (('並進夔龍位，仍齊龜鶴年。同心舟已濟，造膝璧常聯。', '劉禹錫'), '杜甫'),
#  (('麗莫似漢宮妃，謙莫似黃家女。黃女持謙齒發高，', '李白'), '李商隱'),
#  (('山深苦多風，落日童稚饑。悄然村墟迥，煙火何由追。', '杜甫'), '杜甫'),
#  (('江間雖炎瘴，瓜熟亦不早。柏公鎮夔國，滯務茲一掃。', '杜甫'), '杜甫'),
#  (('安得郢中質，一揮成斧斤。', '李白'), '李白'),
#  (('望夫登高山，化石竟不返。', '李白'), '李白'),
#  (('多為裁詩步竹軒，有時凝思過朝昏。篇成敢道懷金璞，', '杜牧'), '劉禹錫'),
#  (('千里一回首，萬里一長歌。黃鶴不復來，清風愁奈何。', '李白'), '李白'),
#  (('門鵲晨光起，牆烏宿處飛。寒江流甚細，有意待人歸。', '杜甫'), '杜甫'),
#  (('晨光映遠岫，夕露見日晞。遲暮少寢食，清曠喜荊扉。', '杜甫'), '杜甫'),
#  (('拔為天軍佐，崇大王法度。淮海生清風，南翁尚思慕。', '杜甫'), '杜甫'),
#  (('山晚浮雲合，歸時恐路迷。澗寒人欲到，村黑鳥應棲。', '杜甫'), '杜甫'),
#  (('客有桂陽至，能吟山鷓鴣。清風動窗竹，越鳥起相呼。', '李白'), '李白'),
#  (('暴尪或前聞，鞭巫非稽古。請先偃甲兵，處分聽人主。', '杜甫'), '杜甫'),
#  (('雲南五月中，頻喪渡瀘師。毒草殺漢馬，張兵奪雲旗。', '李白'), '李白'),
#  (('戍鼓猶長擊，林鶯遂不歌。忽思高宴會，朱袖拂雲和。', '杜甫'), '杜甫'),
#  (('對影聞聲已可憐，玉池荷葉正田田。不逢蕭史休回首，', '李商隱'), '劉禹錫'),
#  (('樂哉弦管客，愁殺戰征兒。因絕西園賞，臨風一詠詩。', '李白'), '李白'),
#  (('歌闋樽殘恨卻偏，憑君不用設離筵。未趨雉尾隨元老，', '杜牧'), '杜甫'),
#  (('雲氣接昆侖，涔涔塞雨繁。羌童看渭水，使客向河源。', '杜甫'), '杜甫'),
#  (('遙知禮數絕，常恐不合併。惕想結宵夢，素心久已冥。', '李白'), '杜甫'),
#  (('昭君坊中多女伴，永安宮外踏青來。', '劉禹錫'), '劉禹錫'),
#  (('昔年嘗聚盜，此日頗分兵。猜貳誰先致，三朝事始平。', '李商隱'), '杜甫'),
#  (('劉侯歎我攜客來，置酒張燈促華饌。且將款曲終今夕，', '杜甫'), '劉禹錫'),
#  (('心馳碧泉澗，目斷青瑣闈。明日武關外，夢魂勞遠飛。', '杜牧'), '李商隱'),
#  (('日晚湘水綠，孤舟無端倪。明湖漲秋月，獨泛巴陵西。', '李白'), '杜牧'),
#  (('紅稠屋角花，碧委牆隅草。親賓縱談謔，喧鬧畏衰老。', '杜甫'), '杜甫'),
#  (('落日驚侵晝，餘光誤惜春。簷冰滴鵝管，屋瓦鏤魚鱗。', '李商隱'), '杜甫'),
#  (('不露文章世已驚，未辭翦伐誰能送。苦心豈免容螻蟻，', '杜甫'), '杜甫'),
#  (('未知所馳逐，但見暮光滅。歸來懸兩狼，門戶有旌節。', '杜甫'), '杜甫'),
#  (('荊州一萬里，不如蒯易度。仰首望飛鳴，伊人何異趣。', '杜牧'), '杜甫'),
#  (('迎風奸吏免，先令疲人喜。何武劾腐儒，陳蕃禮高士。', '劉禹錫'), '劉禹錫'),
#  (('昔升君子堂，腰下綬猶黃。汾陰有寶氣，赤堇多奇鋩。', '劉禹錫'), '杜甫'),
#  (('繁露傳家學，青蓮譯梵書。火風乖四大，文字廢三餘。', '劉禹錫'), '劉禹錫'),
#  (('範子何曾愛五湖，功成名遂身自退。劍是一夫用，', '李白'), '李白'),
#  (('胡床紫玉笛，卻坐青雲叫。楊花滿州城，置酒同臨眺。', '李白'), '杜甫'),
#  (('日出遠海明，軒車且裴回。更游龍潭去，枕石拂莓苔。', '李白'), '李白'),
#  (('飲酒眼前樂，虛名何處有。男兒窮通當有時，', '李白'), '杜甫'),
#  (('東風扇淑氣，水木榮春暉。白日照綠草，落花散且飛。', '李白'), '李白'),
#  (('無數春筍滿林生，柴門密掩斷人行。', '杜甫'), '杜甫'),
#  (('夕烽來不近，每日報平安。塞上傳光小，雲邊落點殘。', '杜甫'), '杜甫'),
#  (('多慚華省貴，不以逐臣疏。複如竹林下，叨陪芳宴初。', '李白'), '劉禹錫'),
#  (('暗飛螢自照，水宿鳥相呼。萬事干戈裏，空悲清夜徂。', '杜甫'), '杜甫'),
#  (('何處深春好，春深刺史家。夜闌猶命樂，雨甚亦尋花。', '劉禹錫'), '劉禹錫'),
#  (('半夜龍驤去，中原虎穴空。隴山兵十萬，嗣子握雕弓。', '杜牧'), '李白'),
#  (('昔帝回沖眷，維皇惻上仁。三靈迷赤氣，萬匯叫蒼旻。', '李商隱'), '劉禹錫'),
#  (('前行無歸日，返顧思舊鄉。慘戚冰雪裏，悲號絕中腸。', '李白'), '杜甫'),
#  (('雲山萬重隔，音信千里絕。春去秋複來，相思幾時歇。', '李白'), '李白'),
#  (('穀口舊相得，濠梁同見招。平生為幽興，未惜馬蹄遙。', '杜甫'), '杜甫'),
#  (('大軍載草草，凋瘵滿膏肓。備員竊補袞，憂憤心飛揚。', '杜甫'), '杜甫'),
#  (('拱木臨周道，荒廬積古苔。魚因感薑出，鶴為吊陶來。', '李商隱'), '李白'),
#  (('李白乘舟將欲行，忽聞岸上踏歌聲。', '李白'), '李白'),
#  (('肅宗複社稷，得無逆順辨。范曄顧其兒，李斯憶黃犬。', '杜甫'), '杜甫'),
#  (('正是客心孤回處，誰家紅袖憑江樓。', '杜牧'), '李商隱'),
#  (('古來聖賢皆寂寞，惟有飲者留其名。陳王昔時宴平樂，', '李白'), '劉禹錫'),
#  (('紅羅袖裏分明見，白玉盤中看卻無。', '李白'), '劉禹錫'),
#  (('悲笳數聲動，壯士慘不驕。借問大將誰，恐是霍嫖姚。', '杜甫'), '杜甫'),
#  (('暮景巴蜀僻，春風江漢清。晉山雖自棄，魏闕尚含情。', '杜甫'), '杜甫'),
#  (('優遊謝康樂，放浪陶彭澤。吾衰未自安，謝爾性所適。', '杜甫'), '杜甫'),
#  (('陳留風俗衰，人物世不數。塞上得阮生，迥繼先父祖。', '杜甫'), '杜甫'),
#  (('君不聞漢家山東二百州，千村萬落生荊杞。', '杜甫'), '杜甫'),
#  (('延陵有寶劍，價重千黃金。觀風曆上國，暗許故人深。', '李白'), '李白'),
#  (('西閣百尋餘，中宵步綺疏。飛星過水白，落月動沙虛。', '杜甫'), '杜甫'),
#  (('尚念四小松，蔓草易拘纏。霜骨不甚長，永為鄰里憐。', '杜甫'), '杜甫'),
#  (('羲和羲和，汝奚汩沒於荒淫之波。魯陽何德，駐景揮戈。', '李白'), '杜甫'),
#  (('是老胡雞犬，鳴舞飛帝鄉。淋漓颯遝，進退成行。能胡歌，', '李白'), '李白'),
#  (('又如洞房冷，翠被張穹籠。亦若暨羅女，平旦妝顏容。', '李商隱'), '李白'),
#  (('靜眠依翠荇，暖戲折高荷。山陰豈無爾，繭字換群鵝。', '杜牧'), '杜甫'),
#  (('西晉樓船下益州，金陵王氣黯然收。千尋鐵鎖沉江底，', '劉禹錫'), '杜甫'),
#  (('高高至天門，日觀近可攀。雲山望不及，此去何時還。', '李白'), '李白'),
#  (('安知慕群客，彈劍拂秋蓮。', '李白'), '李白'),
#  (('典郡終微眇，治中實棄捐。安排求傲吏，比興展歸田。', '杜甫'), '杜甫'),
#  (('井絡天彭一掌中，漫誇天設劍為峰。陣圖東聚燕江石，', '李商隱'), '李白'),
#  (('轉蓬憂悄悄，行藥病涔涔。瘞夭追潘岳，持危覓鄧林。', '杜甫'), '杜甫'),
#  (('春向晚，春晚思悠哉。風雲日已改，花葉自相催。', '劉禹錫'), '杜甫'),
#  (('四字香書印，三乘壁畫車。遲回聽句偈，雙樹晚陰斜。', '劉禹錫'), '劉禹錫'),
#  (('閉藏修鱗蟄，出入巨石礙。何事暑天過，快意風雨會。', '杜甫'), '杜甫'),
#  (('何當共剪西窗燭，卻話巴山夜雨時。', '李商隱'), '杜牧'),
#  (('坦腹東床下，由來志氣疏。遙知向前路，擲果定盈車。', '李白'), '杜甫'),
#  (('封內必舞雩，峽中喧擊鼓。真龍竟寂寞，土梗空俯僂。', '杜甫'), '杜甫'),
#  (('男兒百年且榮身，何須徇節甘風塵。衣冠半是征戰士，', '李白'), '劉禹錫'),
#  (('絕域長夏晚，茲樓清宴同。朝廷燒棧北，鼓角滿天東。', '杜甫'), '杜甫'),
#  (('繼體三才理，承顏九族親。禹功留海內，殷曆付天倫。', '劉禹錫'), '杜甫'),
#  (('清江一曲抱村流，長夏江村事事幽。自去自來堂上燕，', '杜甫'), '杜牧'),
#  (('禁庭春晝，鶯羽披新繡。百草巧求花下鬥，只賭珠璣滿鬥。', '李白'), '杜甫'),
#  (('函谷絕飛鳥，武關擁連營。意在斬巨鼇，何論鱠長鯨。', '李白'), '杜甫'),
#  (('鞔鼓畫麒麟，看君擊狂節。離袖颭應勞，恨粉啼還咽。', '杜牧'), '李商隱'),
#  (('大哉霜雪幹，歲久為枯林。', '杜甫'), '杜甫'),
#  (('寒水光難定，秋山響易哀。天涯稍曛黑，倚杖更裴回。', '杜甫'), '杜甫'),
#  (('此花不逐溪流出，晉客無因入洞來。', '杜牧'), '李白'),
#  (('漢帝長楊苑，誇胡羽獵歸。子雲叨侍從，獻賦有光輝。', '李白'), '李白'),
#  (('西北樓成雄楚都，遠開山嶽散江湖。二儀清濁還高下，', '杜甫'), '李白'),
#  (('素幔隨流水，歸舟返舊京。老親如宿昔，部曲異平生。', '杜甫'), '杜甫'),
#  (('秋雨離情動，新詩樂府傳。聆音還竊抃，不覺撫麼弦。', '劉禹錫'), '劉禹錫'),
#  (('束帶謬趨文石陛，有章曾拜皂囊封。期嚴無奈睡留癖，', '杜牧'), '杜牧'),
#  (('初生欲缺虛惆悵，未必圓時即有情。', '李商隱'), '李商隱'),
#  (('白榜千家邑，清秋萬估船。詞人取佳句，刻畫竟誰傳。', '杜甫'), '劉禹錫'),
#  (('苦搖求食尾，常曝報恩腮。結舌防讒柄，探腸有禍胎。', '杜甫'), '杜甫'),
#  (('邛州崔錄事，聞在果園坊。久待無消息，終朝有底忙。', '杜甫'), '杜甫'),
#  (('開花必早落，桃李不如松。管鮑久已死，何人繼其蹤。', '李白'), '李白'),
#  (('地用莫如馬，無良複誰記。此日千里鳴，追風可君意。', '杜甫'), '杜甫'),
#  (('哀哉桃林戰，百萬化為魚。請囑防關將，慎勿學哥舒。', '杜甫'), '杜甫'),
#  (('柳暗將翻巷，荷欹正抱橋。鈿轅開道入，金管隔鄰調。', '李商隱'), '杜甫'),
#  (('君行別老親，此去苦家貧。藻鏡留連客，江山憔悴人。', '杜甫'), '李白'),
#  (('天子巡劍閣，儲皇守扶風。揚袂正北辰，開襟攬群雄。', '李白'), '李白'),
#  (('獨折南園一朵梅，重尋幽坎已生苔。', '杜牧'), '杜牧'),
#  (('雙樹容聽法，三車肯載書。草玄吾豈敢，賦或似相如。', '杜甫'), '杜甫'),
#  (('林昏罷幽磬，竟夜伏石閣。王喬下天壇，微月映皓鶴。', '杜甫'), '杜甫'),
#  (('意答兒童問，來經戰伐新。泊船悲喜後，款款話歸秦。', '杜甫'), '杜甫'),
#  (('韓信羞將絳灌比，禰衡恥逐屠沽兒。君不見李北海，', '李白'), '李白'),
#  (('好樹鳴幽鳥，晴樓入野煙。殘春杜陵客，中酒落花前。', '杜牧'), '劉禹錫'),
#  (('且樂生前一杯酒，何須身後千載名。', '李白'), '李白'),
#  (('修文將管輅，奉使失張騫。史閣行人在，詩家秀句傳。', '杜甫'), '杜甫'),
#  (('妾在舂陵東，君居漢江島。一日望花光，往來成白道。', '李白'), '李白'),
#  (('焉能終日心拳拳，憶君誦詩神凜然。辛夷始花亦已落，', '杜甫'), '杜甫'),
#  (('仙游渡潁水，訪隱同元君。忽遺蒼生望，獨與洪崖群。', '李白'), '李白'),
#  (('虛傳一片雨，枉作陽臺神。縱為夢裏相隨去，', '李白'), '李商隱'),
#  (('醉舞紛綺席，清歌繞飛梁。歡娛未終朝，秩滿歸咸陽。', '李白'), '李白'),
#  (('兵家忌間諜，此輩常接跡。台中領舉劾，君必慎剖析。', '杜甫'), '杜甫'),
#  (('蟬吟秋色樹，鴉噪夕陽沙。不擬徹雙鬢，他方擲歲華。', '杜牧'), '李白'),
#  (('失計拋魚艇，何門化涸鱗。是誰添歲月，老卻暗投人。', '杜牧'), '杜牧'),
#  (('稍待西風涼冷後，高尋白帝問真源。', '杜甫'), '杜甫'),
#  (('肘後符應驗，囊中藥未陳。旅懷殊不愜，良覿渺無因。', '杜甫'), '李商隱'),
#  (('蘭舟倚行棹，桂酒掩餘樽。重此一留宿，前汀煙月昏。', '杜牧'), '杜牧'),
#  (('已帶黃金縷，仍飛白玉花。長時須拂馬，密處少藏鴉。', '李商隱'), '杜甫'),
#  (('水綠南熏殿，花紅北闕樓。鶯歌聞太液，鳳吹繞瀛洲。', '李白'), '李白'),
#  (('流塵翳明鏡，歲久看如漆。門前負局人，為我一磨拂。', '劉禹錫'), '劉禹錫'),
#  (('為是襄王故宮地，至今猶自細腰多。', '劉禹錫'), '杜甫'),
#  (('旄頭彗紫微，無複俎豆事。金甲相排蕩，青衿一憔悴。', '杜甫'), '杜牧'),
#  (('北辰當宇宙，南嶽據江湖。國帶風塵色，兵張虎豹符。', '杜甫'), '杜甫'),
#  (('少年苦不久，顧慕良難哉。徒令真珠肶，裛入珊瑚腮。', '李商隱'), '杜甫'),
#  (('熊兒幸無恙，驥子最憐渠。臨老羈孤極，傷時會合疏。', '杜甫'), '杜甫'),
#  (('曆聘不能用，領徒空爾為。儒風正禮樂，旅象入蓍龜。', '劉禹錫'), '杜甫'),
#  (('越鳥從南來，胡鷹亦北度。我欲彎弓向天射，', '李白'), '李白'),
#  (('牢落官軍速，蕭條萬事危。鬢毛元自白，淚點向來垂。', '杜甫'), '杜甫'),
#  (('君王棄北海，掃地借長鯨。呼吸走百川，燕然可摧傾。', '李白'), '李白'),
#  (('嵯峨白帝城東西，南有龍湫北虎溪。吾孫騎曹不騎馬，', '杜甫'), '杜甫'),
#  (('攜妓東土山，悵然悲謝安。我妓今朝如花月，', '李白'), '李白'),
#  (('人情見非類，田家戒其荒。功夫競搰搰，除草置岸旁。', '杜甫'), '杜甫'),
#  (('六曲連環接翠帷，高樓半夜酒醒時。', '李商隱'), '杜牧'),
#  (('族父領元戎，名聲國中老。奪我同官良，飄搖按城堡。', '杜甫'), '杜甫'),
#  (('川色晴猶遠，烏聲暮欲棲。唯餘踏青伴，待月魏王堤。', '劉禹錫'), '劉禹錫'),
#  (('莫恨名姬中夜沒，君王猶自不長生。', '李商隱'), '李商隱'),
#  (('舍舟共連袂，行上南渡橋。興發歌綠水，秦客為之搖。', '李白'), '李白'),
#  (('戰國何紛紛，兵戈亂浮雲。趙倚兩虎鬥，晉為六卿分。', '李白'), '李白'),
#  (('低頭向暗壁，千喚不一回。十五始展眉，願同塵與灰。', '李白'), '杜牧'),
#  (('畫角吹秦晉，旄頭俯澗瀍。小儒輕董卓，有識笑苻堅。', '杜甫'), '杜甫'),
#  (('吐辭又炳煥，五色羅華星。秀句滿江國，高才掞天庭。', '李白'), '杜甫'),
#  (('那解將心憐孔翠，羈雌長共故雄分。', '李商隱'), '李商隱'),
#  (('有策不敢犯龍鱗，竄身南國避胡塵。寶書長劍掛高閣，', '李白'), '李白'),
#  (('高唐暮冬雪壯哉，舊瘴無複似塵埃。崖沉穀沒白皚皚，', '杜甫'), '杜甫'),
#  (('當時上紫殿，不獨卿相尊。世傳閭丘筆，峻極逾昆侖。', '杜甫'), '杜甫'),
#  (('送別枯桑下，凋葉落半空。我行懵道遠，爾獨知天風。', '李白'), '李白'),
#  (('屬國歸何晚，樓蘭斬未還。煙塵獨長望，衰颯正摧顏。', '杜甫'), '李白'),
#  (('遭逢二明主，前後兩遷逐。去國愁夜郎，投身竄荒穀。', '李白'), '李白'),
#  (('我聞照妖鏡，及與神劍鋒。寓身會有地，不為凡物蒙。', '李商隱'), '杜甫'),
#  (('壯心屈黃綬，浪跡寄滄洲。昨觀荊峴作，如從雲漢遊。', '李白'), '李白'),
#  (('桂席塵瑤佩，瓊爐燼水沉。凝魂空薦夢，低耳悔聽琴。', '杜牧'), '杜牧'),
#  (('宮掖方為蠱，邊隅忽遘迍。獻書秦逐客，間諜漢名臣。', '李商隱'), '杜甫'),
#  (('夷落遙知真漢相，爭來屈膝看儀刑。', '劉禹錫'), '劉禹錫'),
#  (('東郊瘦馬使我傷，骨骼硉兀如堵牆。絆之欲動轉欹側，', '杜甫'), '杜甫'),
#  (('手持錦袍覆我身，我醉橫眠枕其股。當筵意氣淩九霄，', '李白'), '李白'),
#  (('弱水應無地，陽關已近天。今君渡沙磧，累月斷人煙。', '杜甫'), '李白'),
#  (('部內有良牧，望中寄深情。臨觴念佳期，泛瑟動離聲。', '劉禹錫'), '劉禹錫'),
#  (('近接西南境，長懷十九泉。何時一茅屋，送老白雲邊。', '杜甫'), '杜甫'),
#  (('吳江賦鸚鵡，落筆超群英。鏘鏘振金玉，句句欲飛鳴。', '李白'), '杜甫'),
#  (('斑竹枝，斑竹枝，淚痕點點寄相思。楚客欲聽瑤瑟怨，', '劉禹錫'), '杜甫'),
#  (('幽響滴岩溜，晴芳飄野叢。海雲懸颶母，山果屬狙公。', '劉禹錫'), '杜牧'),
#  (('少年留取多情興，請待花時作主人。', '劉禹錫'), '劉禹錫'),
#  (('夢覺疑連榻，舟行忽千里。不見黃鶴樓，寒沙雪相似。', '劉禹錫'), '李白'),
#  (('密竹沈虛籟，孤蓮泊晚香。如何此幽勝，淹臥劇清漳。', '李商隱'), '杜甫'),
#  (('自哂成書簏，終當咒酒卮。懶沾襟上血，羞鑷鏡中絲。', '李商隱'), '杜甫'),
#  (('兩都開幕府，萬宇插軍麾。南海殘銅柱，東風避月支。', '杜甫'), '杜甫'),
#  (('流血塗野草，豺狼盡冠纓。', '李白'), '杜甫'),
#  ...]
